# %% [markdown]
# # CS440/ECE448 Spring 2023
# # MP11: Reinforcement Learning

# %% [markdown]
# The first thing you need to do is to download this file: <a href="mp11.zip">mp11.zip</a>.  If you want, you can also download <a href="mp11_extra.zip">mp11_extra.zip</a>, the extra credit assignment.  `mp11.zip` has the following content:
#
# * `submitted.py`: Your homework. Edit, and then submit to <a href="https://www.gradescope.com/courses/486387">Gradescope</a>.
# * `mp11_notebook.ipynb`: This is a <a href="https://anaconda.org/anaconda/jupyter">Jupyter</a> notebook to help you debug.  You can completely ignore it if you want, although you might find that it gives you useful instructions.
# * `pong.py`: This is a program that plays Pong.  If called interactively, it will call the module `pong_display.py` to create a display, so that you can play.  If told to use a Q-learner, it will call your `submitted.py` to do Q-learning.
# * `grade.py`: Once your homework seems to be working, you can test it by typing `python grade.py`, which will run the tests in `tests/tests_visible.py`.
# * `tests/test_visible.py`: This file contains about half of the <a href="https://docs.python.org/3/library/unittest.html">unit tests</a> that Gradescope will run in order to grade your homework.  If you can get a perfect score on these tests, then you should also get a perfect score on the additional hidden tests that Gradescope uses.
# * `requirements.txt`: This tells you which python packages you need to have installed, in order to run `grade.py`.  You can install all of those packages by typing `pip install -r requirements.txt` or `pip3 install -r requirements.txt`.

# %% [markdown]
# This file (`mp11_notebook.ipynb`) will walk you through the whole MP, giving you instructions and debugging tips as you go.
#
# ### Table of Contents
#
# 1. <a href="#section1">Playing Pong</a>
# 1. <a href="#section2">Creating a Q-Learner Object</a>
# 1. <a href="#section3">Epsilon-First Exploration</a>
# 1. <a href="#section4">Q-Learning</a>
# 1. <a href="#section5">Saving and Loading Your Q and N Tables</a>
# 1. <a href="#section6">Exploitation</a>
# 1. <a href="#section7">Acting</a>
# 1. <a href="#section8">Training</a>
# 1. <a href="#section9">Extra Credit</a>
# 1. <a href="#grade">Grade Your Homework</a>

# %% [markdown]
# <a id='section1'></a>

# %% [markdown]
# ## Playing Pong

# %% [markdown]
# Pong was the <a href="https://en.wikipedia.org/wiki/Pong">first video game produced by Atari.</a>  It is a simple game, based on table tennis.  Here is a two-person version of the game: https://commons.wikimedia.org/wiki/File:Pong_Game_Test2.gif
#
# We will be playing a one-person version of the game:
#
# * When the ball hits the top, bottom, or left wall of the playing field, it bounces.
# * The right end of the playing field is open, except for the paddle.  If the ball hits the paddle, it bounces, and the player's score increments by one.  If the ball hits the open space, the game is over; the score resets to zero, and a new game begins.
#
# The game is pretty simple, but in order to get a better feeling for it, you may want to try playing it yourself.  Use the up arrow to move the paddle upward, and the down arrow to move the paddle downward.  See how high you can make your score:

# %%
# !python pong.py
# Out:
# pygame 2.1.3 (SDL 2.0.22, Python 3.10.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 2023-04-23 10:02:26.688 python[37097:2562925] TSM AdjustCapsLockLEDForKeyTransitionHandling - _ISSetPhysicalKeyboardCapsLockLED Inhibit
# Completed 0 games, 3 rewards, 1084 frames, score 2, max score 2
# Completed 1 games, 15 rewards, 5123 frames, score 11, max score 11

# %% [markdown]
# Once you figure out how to use the arrow keys to control your paddle, we hope you will find that the game is not too hard for a human to play.  However, for a computer, it's difficult to know: where should the paddle be moved at each time step?  In order to see how difficult it is for a computer to play, let's ask the "random" player to play the game.
#
# **WARNING:** The following line will open a pygame window.  The pygame window will be hidden by this window -- in order to see it, you will need to minimize this window.  The pygame window will consume a lot of CPU time just waiting for the processor, so in order to kill it, you will need to come back to this window, click on the block below, then click the Jupyter "stop" button (the square button at the top of this window) in order to stop processing.

# %%
# !python pong.py --player random
# Out:
# pygame 2.1.3 (SDL 2.0.22, Python 3.10.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Completed 0 games, 1 rewards, 182 frames, score 0, max score 0
# Completed 1 games, 2 rewards, 363 frames, score 0, max score 0
# ^C
# Traceback (most recent call last):
#   File "/Users/elijahye/Desktop/ECE 448/AI_Repo/mp11/pong.py", line 270, in <module>
#     application.run()
#   File "/Users/elijahye/Desktop/ECE 448/AI_Repo/mp11/pong.py", line 170, in run
#     self.display.update_display()
#   File "/Users/elijahye/Desktop/ECE 448/AI_Repo/mp11/pong_display.py", line 65, in update_display
#     self.fps.tick(60)
# KeyboardInterrupt

# %% [markdown]
# <a id='section2'></a>

# %% [markdown]
# ## Creating a Q-Learner Object

# %% [markdown]
# The first thing you will do is to create a `q_learner` object that can store your learned Q table and your N table (table of exploration counts).
#
# Like any other object-oriented language, python permits you to create new object classes in order to store data that will be needed from time to time.  If you are not already very, very familiar with python classes, you might want to study the python class tutorial: https://docs.python.org/3/tutorial/classes.html
#
# Like any other object in python, a `q_learner` object is created by calling its name as a function, e.g., `my_q_learner=submitted.q_learner()`.  Doing so calls the function `submitted.q_learner.__init__()`.  Let's look at the docstring to see what it should do.

# %%
import submitted, importlib
importlib.reload(submitted)
help(submitted.q_learner.__init__)
# Out:
# Help on function __init__ in module submitted:
#
# __init__(self, alpha, epsilon, gamma, nfirst, state_cardinality)
#     Create a new q_learner object.
#     Your q_learner object should store the provided values of alpha,
#     epsilon, gamma, and nfirst.
#     It should also create a Q table and an N table.
#     Q[...state..., ...action...] = expected utility of state/action pair.
#     N[...state..., ...action...] = # times state/action has been explored.
#     Both are initialized to all zeros.
#     Up to you: how will you encode the state and action in order to
#     define these two lookup tables?  The state will be a list of 5 integers,
#     such that 0 <= state[i] < state_cardinality[i] for 0 <= i < 5.
#     The action will be either -1, 0, or 1.
#     It is up to you to decide how to convert an input state and action
#     into indices that you can use to access your stored Q and N tables.
#
#     @params:
#     alpha (scalar) - learning rate of the Q-learner
#     epsilon (scalar) - probability of taking a random action
#     gamma (scalar) - discount factor
#     nfirst (scalar) - exploring each state/action pair nfirst times before exploiting
#     state_cardinality (list) - cardinality of each of the quantized state variables
#
#     @return:
#     None

# %% [markdown]
# Write your `__init__` function to meet the requirements specified in the docstring.  Once you have completed it, the following code should run without errors:

# %%
importlib.reload(submitted)

q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])

print(q_learner)
# Out:
# <submitted.q_learner object at 0x7fd061b6bcd0>

# %% [markdown]
# <a id='section3'></a>

# %% [markdown]
# ## Epsilon-First Exploration

# %% [markdown]
# In order to manage the exploration/exploitation tradeoff, we will be using both "epsilon-first" and "epsilon-greedy" (https://en.wikipedia.org/wiki/Multi-armed_bandit#Semi-uniform_strategies).
#
# The epsilon-first strategy explores every state/action pair at least `nfirst` times before it ever starts to exploit any strategy.  Your `q_learner` should have a table to keep track of how many times it has explored a state/action pair prior to the start of any exploitation.  The method for storing that table is up to you; in order to have some standardized API, therefore, you need to write a method called `report_exploration_counts` that returns a list of the three exploration counts for a given state.

# %%
importlib.reload(submitted)
help(submitted.q_learner.report_exploration_counts)
# Out:
# Help on function report_exploration_counts in module submitted:
#
# report_exploration_counts(self, state)
#     Check to see how many times each action has been explored in this state.
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     explored_count (array of 3 ints):
#       number of times that each action has been explored from this state.
#       The mapping from actions to integers is up to you, but there must be three of them.

# %% [markdown]
# Write `report_exploration_counts` so that it returns a list or array for any given state.  Test your code with the following:

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('This is how many times state [0,0,0,0,0] has been explored so far:')
print(q_learner.report_exploration_counts([0,0,0,0,0]))
print('This is how many times state [9,9,1,1,9] has been explored so far:')
print(q_learner.report_exploration_counts([9,9,1,1,9]))
# Out:
# This is how many times state [0,0,0,0,0] has been explored so far:
# [0. 0. 0.]
# This is how many times state [9,9,1,1,9] has been explored so far:
# [0. 0. 0.]

# %% [markdown]
# When your learner first starts learning, it will call the function `choose_unexplored_action` to choose an unexplored action.  This function should choose a function uniformly at random from the set of unexplored actions in a given state, if there are any:

# %%
importlib.reload(submitted)
help(submitted.q_learner.choose_unexplored_action)
# Out:
# Help on function choose_unexplored_action in module submitted:
#
# choose_unexplored_action(self, state)
#     Choose an action that has been explored less than nfirst times.
#     If many actions are underexplored, you should choose uniformly
#     from among those actions; don't just choose the first one all
#     the time.
#
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#        These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     action (scalar): either -1, or 0, or 1, or None
#       If all actions have been explored at least n_explore times, return None.
#       Otherwise, choose one uniformly at random from those w/count less than n_explore.
#       When you choose an action, you should increment its count in your counter table.

# %% [markdown]
# If this has been written correctly, the following block should generate a random sequence of actions.  If the next block produces the same action 5 times in a row, that is the wrong result, and the result would be that your code does not pass the autograder.

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
# Out:
# Next action: 1
# Next action: 1
# Next action: 1
# Next action: 0
# Next action: -1

# %% [markdown]
# After all three actions have been explored `nfirst` times, the function `choose_unexplored_action` should return `None`, as shown here:

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,1,[10,10,2,2,10])
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
print('Next action:',q_learner.choose_unexplored_action([9,9,1,1,9]))
# Out:
# Next action: 0
# Next action: -1
# Next action: 1
# Next action: None

# %% [markdown]
# <a id='section4'></a>

# %% [markdown]
# ## Q-Learning

# %% [markdown]
# The reinforcement learning we are implementing is called Q-learning (https://en.wikipedia.org/wiki/Q-learning).
#
# Q-learning keeps a table $Q[s,a]$ that specifies the expected utility of action $a$ in state $s$.  The organization of this table is up to you.  In order to have a standard API, the first thing you should implement is a function `report_q` with the following docstring:

# %%
importlib.reload(submitted)
help(submitted.q_learner.report_q)
# Out:
# Help on function report_q in module submitted:
#
# report_q(self, state)
#     Report the current Q values for the given state.
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     Q (array of 3 floats):
#       reward plus expected future utility of each of the three actions.
#       The mapping from actions to integers is up to you, but there must be three of them.

# %% [markdown]
# When your `q_learner` is first initialized, the value of $Q[state,action]$ should be zero for all state/action pairs, thus the `report_q` function should return lists of zeros:

# %%
importlib.reload(submitted)
q_learner=submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Q[0,0,0,0,0] is now:',q_learner.report_q([0,0,0,0,0]))
print('Q[9,9,1,1,9] is now:',q_learner.report_q([9,9,1,1,9]))
# Out:
# Q[0,0,0,0,0] is now: [0. 0. 0.]
# Q[9,9,1,1,9] is now: [0. 0. 0.]

# %% [markdown]
# There are actually many different Q-learning algorithms available, but when people refer to Q-learning with no modifier, they usually mean the time-difference (TD) algorithm.  For example, this is the algorithm that's described on the wikipedia page (https://en.wikipedia.org/wiki/Q-learning).  This is the algorithm you will implement for this MP.
#
# In supervised machine learning, the learner tries to imitate a reference label.  In reinforcement learning, there is no reference label.  Q-learning replaces the reference label with a "local Q" value, which is the utility that was obtained by performing action $a$ in state $s$ one time.  It is usually calculated like this:
#
# $$Q_{local}(s_t,a_t) = r_t + \gamma\max_{a_{t+1}}Q(s_{t+1},a_{t+1})$$
#
# where $r_t$ is the reward that was achieved by performing action $a_t$ in state $s_t$, $s_{t+1}$ is the state into which the game transitioned, and $a_{t+1}$ is one of the actions that could be performed in that state.  $Q_{local}$ is computed by your `q_local` function, which has this docstring:

# %%
importlib.reload(submitted)
help(submitted.q_learner.q_local)
# Out:
# Help on function q_local in module submitted:
#
# q_local(self, reward, newstate)
#     The update to Q estimated from a single step of game play:
#     reward plus gamma times the max of Q[newstate, ...].
#
#     @param:
#     reward (scalar float): the reward achieved from the current step of game play.
#     newstate (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     Q_local (scalar float): the local value of Q

# %% [markdown]
# Initially, `q_local` should just return the given reward, because initially, all Q values are 0:

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,10,10])
print('Q_local(6.25,[9,9,1,1,9]) is currently:',q_learner.q_local(6.25,[9,9,1,1,9]))
# Out:
# Q_local(6.25,[9,9,1,1,9]) is currently: 6.25

# %% [markdown]
# Now you can use `q_learner.q_local` as the target for `q_learner.learn`.  The basic algorithm is
#
# $$Q(s,a) = Q(s,a) + \alpha (Q_{local}(s,a)-Q(s,a))$$
#
# Here is the docstring:

# %%
importlib.reload(submitted)
help(submitted.q_learner.learn)
# Out:
# Help on function learn in module submitted:
#
# learn(self, state, action, reward, newstate)
#     Update the internal Q-table on the basis of an observed
#     state, action, reward, newstate sequence.
#
#     @params:
#     state: a list of 5 numbers: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle.
#     action: an integer, one of -1, 0, or +1
#     reward: a reward; positive for hitting the ball, negative for losing a game
#     newstate: a list of 5 numbers, in the same format as state
#
#     @return:
#     None

# %% [markdown]
# The following block checks a sequence of Q updates:
#
# 1. First, $Q([9,9,1,1,9],-1)$ is updated.  Since all Q values start at zero, it will be updated to just have a value equal to $\alpha$ (0.05) times the given reward (6.25) for a total value of 0.3125.
# 1. When we print out $Q([9,9,1,1,9],:)$, we see that one of the elements has been updated.
# 1. Next, update $Q([9,9,1,1,8],1)$ with a given reward, and with $[9,9,1,1,9]$ as the given next state.  Since $Q([9,9,1,1,9],-1)$ is larger than zero, the next-state Q-value should be multiplied by $\gamma$ (0.99) and added to the reward (3.1), then multiplied by $\alpha$, giving a total value of 0.17046875.
# 1. The resulting Q-value is reported.

# %%
importlib.reload(submitted)
q_learner = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
q_learner.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('Q[9,9,1,1,9] is now',q_learner.report_q([9,9,1,1,9]))
q_learner.learn([9,9,1,1,8],1,3.1,[9,9,1,1,9])
print('Q[9,9,1,1,8] is now',q_learner.report_q([9,9,1,1,8]))
# Out:
# Q[9,9,1,1,9] is now [0.     0.     0.3125]
# Q[9,9,1,1,8] is now [0.         0.17046875 0.        ]

# %% [markdown]
# <a id='section5'></a>

# %% [markdown]
# ## Saving and Loading your Q and N Tables

# %% [markdown]
# After you've spent a long time training your `q_learner`, you will want to save your Q and N tables so that you can reload them later.  The format of Q and N is up to you, therefore it's also up to you to write the `save` and `load` functions.  Here are the docstrings:

# %%
importlib.reload(submitted)
help(submitted.q_learner.save)
# Out:
# Help on function save in module submitted:
#
# save(self, filename)
#     Save your Q and N tables to a file.
#     This can save in any format you like, as long as your "load"
#     function uses the same file format.  We recommend numpy.savez,
#     but you can use something else if you prefer.
#
#     @params:
#     filename (str) - filename to which it should be saved
#     @return:
#     None

# %%
importlib.reload(submitted)
help(submitted.q_learner.load)
# Out:
# Help on function load in module submitted:
#
# load(self, filename)
#     Load the Q and N tables from a file.
#     This should load from whatever file format your save function
#     used.  We recommend numpy.load, but you can use something
#     else if you prefer.
#
#     @params:
#     filename (str) - filename from which it should be loaded
#     @return:
#     None

# %% [markdown]
# These functions can be tested by doing one step of training one `q_learner`, then saving its results, then loading them into another `q_learner`:

# %%
importlib.reload(submitted)
q_learner1 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('Next action:',q_learner1.choose_unexplored_action([9,9,1,1,9]))
q_learner1.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('N1[9,9,1,1,8] is now',q_learner1.report_exploration_counts([9,9,1,1,9]))
print('Q1[9,9,1,1,8] is now',q_learner1.report_q([9,9,1,1,9]))
q_learner1.save('test.npz')

q_learner2 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
print('N2[9,9,1,1,8] starts out as',q_learner2.report_exploration_counts([9,9,1,1,9]))
print('Q2[9,9,1,1,8] starts out as',q_learner2.report_q([9,9,1,1,9]))
q_learner2.load('test.npz')
print('N2[9,9,1,1,8] is now',q_learner2.report_exploration_counts([9,9,1,1,9]))
print('Q2[9,9,1,1,8] is now',q_learner2.report_q([9,9,1,1,9]))
# Out:
# Next action: 0
# N1[9,9,1,1,8] is now [1. 0. 0.]
# Q1[9,9,1,1,8] is now [0.     0.     0.3125]
# N2[9,9,1,1,8] starts out as [0. 0. 0.]
# Q2[9,9,1,1,8] starts out as [0. 0. 0.]
# N2[9,9,1,1,8] is now [1. 0. 0.]
# Q2[9,9,1,1,8] is now [0.     0.     0.3125]

# %% [markdown]
# <a id='section6'></a>

# %% [markdown]
# ## Exploitation

# %% [markdown]
# A reinforcement learner always has to trade off between exploration (choosing an action at random) versus exploitation (choosing the action with the maximum expected utility).  Before we worry about that tradeoff, though, let's first make sure that exploitation works.

# %%
importlib.reload(submitted)
help(submitted.q_learner.exploit)
# Out:
# Help on function exploit in module submitted:
#
# exploit(self, state)
#     Return the action that has the highest Q-value for the current state, and its Q-value.
#     @params:
#     state (list of 5 ints): ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     action (scalar int): either -1, or 0, or 1.
#       The action that has the highest Q-value.  Ties can be broken any way you want.
#     Q (scalar float):
#       The Q-value of the selected action

# %%
importlib.reload(submitted)
q_learner1 = submitted.q_learner(0.05,0.05,0.99,5,[10,10,2,2,10])
q_learner1.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('Q1[9,9,1,1,9] is now',q_learner1.report_q([9,9,1,1,9]))
print('The best action and Q from state [9,9,1,1,9] are',q_learner1.exploit([9,9,1,1,9]))
# Out:
# Q1[9,9,1,1,9] is now [0.     0.     0.3125]
# The best action and Q from state [9,9,1,1,9] are (-1, 0.3125)

# %% [markdown]
# <a id='section7'></a>

# %% [markdown]
# ## Acting

# %% [markdown]
# When your learner decides which action to perform, it should trade off exploration vs. exploitation using both the epsilon-first and the epsilon-greedy strategies:
# 1. If there is any action that has been explored fewer than `nfirst` times, then choose one of those actions at random.  Otherwise...
# 1. With probability `epsilon`, choose an action at random.  Otherwise...
# 1. Exploit.

# %%
importlib.reload(submitted)
help(submitted.q_learner.act)
# Out:
# Help on function act in module submitted:
#
# act(self, state)
#     Decide what action to take in the current state.
#     If any action has been taken less than nfirst times, then choose one of those
#     actions, uniformly at random.
#     Otherwise, with probability epsilon, choose an action uniformly at random.
#     Otherwise, choose the action with the best Q(state,action).
#
#     @params:
#     state: a list of 5 integers: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#       These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#       and the y-position of the paddle, all quantized.
#       0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#     @return:
#     -1 if the paddle should move upward
#     0 if the paddle should be stationary
#     1 if the paddle should move downward

# %% [markdown]
# In order to test all three types of action (epsilon-first exploration, epsilon-greedy exploration, and exploitation), let's create a learner with `nfirst=1` and `epsilon=0.25`, and set it so that the best action from state `[9,9,1,1,9]` is `-1`.  With these settings, a sequence of calls to `q_learner.act` should produce the following sequence of actions:
#
# 1. The first three actions should include each possible action once.
# 1. After the first three actions, 3/4 of the remaining actions should be `-1`.  The remaining 1/4 should be randomly chosen.

# %%
importlib.reload(submitted)
q_learner=submitted.q_learner(0.05,0.25,0.99,1,[10,10,2,2,10])
q_learner.learn([9,9,1,1,9],-1,6.25,[0,0,0,0,0])
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-first action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
print('An epsilon-greedy explore/exploit action:',q_learner.act([9,9,1,1,9]))
# Out:
# An epsilon-first action: 1
# An epsilon-first action: -1
# An epsilon-first action: 0
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: 1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: 0
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: -1
# An epsilon-greedy explore/exploit action: 1

# %% [markdown]
# <a id='section8'></a>

# %% [markdown]
# ## Training

# %% [markdown]
# Now that all of your components work, you can try training your algorithm.  Do this by giving your `q_learner` as a player to a new `pong.PongGame` object.  Set `visibility=False` so that the `PongGame` doesn't create a new window.

# %%
import pong, importlib, submitted
importlib.reload(pong)
help(pong.PongGame.__init__)
# Out:
# Help on function __init__ in module pong:
#
# __init__(self, ball_speed=4, paddle_speed=8, learner=None, visible=True, state_quantization=[10, 10, 2, 2, 10])
#     Create a new pong game, with a specified player.
#
#     @params:
#     ball_speed (scalar int) - average ball speed in pixels/frame
#     paddle_speed (scalar int) - paddle moves 0, +paddle_speed, or -paddle_speed
#     learner - can be None if the player is human.  If not None, should be an
#       object of type random_learner, submitted.q_learner, or submitted.deep_q.
#     visible (bool) - should this game have an attached pygame window?
#     state_quantization (list) - if not None, state variables are quantized
#       into integers of these cardinalities before being passed to the learner.

# %% [markdown]
# As you can see, we should set `visibility=False` so that the `PongGame` doesn't create a new window.  We should also make sure that the PongGame uses the same state quantization as the learner.

# %%
importlib.reload(pong)
importlib.reload(submitted)
state_quantization = [10,10,2,2,10]
q_learner=submitted.q_learner(0.05,0.05,0.99,5,state_quantization)

pong_game = pong.PongGame(learner=q_learner, visible=False, state_quantization=state_quantization)
print(pong_game)
# Out:
# <pong.PongGame object at 0x7fd061e13c70>

# %% [markdown]
# In order to train our learner, we want it to play the game many times.  To do that we use the PongGame.run function:

# %%
help(pong_game.run)
# Out:
# Help on method run in module pong:
#
# run(m_rewards=inf, m_games=inf, m_frames=inf, states=[]) method of pong.PongGame instance
#     Run the game.
#     @param
#     m_frames (scalar int): maximum number of frames to be played
#     m_rewards (scalar int): maximum number of rewards earned (+ or -)
#     m_games (scalar int): maximum number of games
#     states (list): list of states whose Q-values should be returned
#        each state is a list of 5 ints: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#        These are the (x,y) position of the ball, the (vx,vy) velocity of the ball,
#        and the y-position of the paddle, all quantized.
#        0 <= state[i] < state_cardinality[i], for all i in [0,4].
#
#
#     @return
#     scores (list): list of scores of all completed games
#
#     The following will be returned only if the player is q_learning or deep_q.
#     New elements will be added to these lists once/frame if m_frames is specified,
#     else once/reward if m_rewards is specified, else once/game:
#       q_achieved (list): list of the q-values of the moves that were taken
#       q_states (list): list of the q-values of requested states

# %% [markdown]
# In order to make sure our learner is learning, let's tell `pong_game.run` to output all 3 Q-values of all of the 4000 states in every time step.
#
# To make sure that's not an outrageous amount of data, let's tell it to only output the Q values once/reward, and ask it to only collect 5000 rewards:

# %%
states = [[x,y,vx,vy,py] for x in range(10) for y in range(10) for vx in range(2) for vy in range(2) for py in range(10) ]

scores, q_achieved, q_states = pong_game.run(m_rewards=500, states=states)

print('The number of games played was',len(scores))
print('The number of rewards was',len(q_states))
print('The size of each returned Q-matrix was',q_states[0].shape)
# Out:
# Completed 0 games, 1 rewards, 255 frames, score 0, max score 0
# Completed 1 games, 2 rewards, 436 frames, score 0, max score 0
# Completed 2 games, 3 rewards, 617 frames, score 0, max score 0
# Completed 3 games, 8 rewards, 1456 frames, score 4, max score 4
# Completed 4 games, 10 rewards, 1854 frames, score 1, max score 4
# Completed 5 games, 11 rewards, 2035 frames, score 0, max score 4
# Completed 6 games, 14 rewards, 2627 frames, score 2, max score 4
# Completed 7 games, 16 rewards, 3021 frames, score 1, max score 4
# Completed 8 games, 17 rewards, 3229 frames, score 0, max score 4
# Completed 9 games, 18 rewards, 3410 frames, score 0, max score 4
# Completed 10 games, 19 rewards, 3591 frames, score 0, max score 4
# Completed 11 games, 22 rewards, 4161 frames, score 2, max score 4
# Completed 12 games, 23 rewards, 4415 frames, score 0, max score 4
# Completed 13 games, 24 rewards, 4596 frames, score 0, max score 4
# Completed 14 games, 25 rewards, 4850 frames, score 0, max score 4
# Completed 15 games, 27 rewards, 5264 frames, score 1, max score 4
# Completed 16 games, 28 rewards, 5472 frames, score 0, max score 4
# Completed 17 games, 29 rewards, 5680 frames, score 0, max score 4
# Completed 18 games, 32 rewards, 6211 frames, score 2, max score 4
# Completed 19 games, 33 rewards, 6465 frames, score 0, max score 4
# Completed 20 games, 34 rewards, 6673 frames, score 0, max score 4
# Completed 21 games, 35 rewards, 6854 frames, score 0, max score 4
# Completed 22 games, 37 rewards, 7206 frames, score 1, max score 4
# Completed 23 games, 39 rewards, 7573 frames, score 1, max score 4
# Completed 24 games, 40 rewards, 7754 frames, score 0, max score 4
# Completed 25 games, 41 rewards, 7935 frames, score 0, max score 4
# Completed 26 games, 42 rewards, 8189 frames, score 0, max score 4
# Completed 27 games, 47 rewards, 9953 frames, score 4, max score 4
# Completed 28 games, 48 rewards, 10161 frames, score 0, max score 4
# Completed 29 games, 49 rewards, 10369 frames, score 0, max score 4
# Completed 30 games, 50 rewards, 10550 frames, score 0, max score 4
# Completed 31 games, 51 rewards, 10731 frames, score 0, max score 4
# Completed 32 games, 55 rewards, 11837 frames, score 3, max score 4
# Completed 33 games, 56 rewards, 12091 frames, score 0, max score 4
# Completed 34 games, 58 rewards, 12681 frames, score 1, max score 4
# Completed 35 games, 59 rewards, 12889 frames, score 0, max score 4
# Completed 36 games, 60 rewards, 13097 frames, score 0, max score 4
# Completed 37 games, 61 rewards, 13305 frames, score 0, max score 4
# Completed 38 games, 63 rewards, 13895 frames, score 1, max score 4
# Completed 39 games, 64 rewards, 14149 frames, score 0, max score 4
# Completed 40 games, 65 rewards, 14403 frames, score 0, max score 4
# Completed 41 games, 66 rewards, 14611 frames, score 0, max score 4
# Completed 42 games, 67 rewards, 14792 frames, score 0, max score 4
# Completed 43 games, 68 rewards, 15046 frames, score 0, max score 4
# Completed 44 games, 71 rewards, 16068 frames, score 2, max score 4
# Completed 45 games, 72 rewards, 16276 frames, score 0, max score 4
# Completed 46 games, 73 rewards, 16457 frames, score 0, max score 4
# Completed 47 games, 74 rewards, 16638 frames, score 0, max score 4
# Completed 48 games, 78 rewards, 19217 frames, score 3, max score 4
# Completed 49 games, 81 rewards, 19987 frames, score 2, max score 4
# Completed 50 games, 82 rewards, 20241 frames, score 0, max score 4
# Completed 51 games, 83 rewards, 20449 frames, score 0, max score 4
# Completed 52 games, 84 rewards, 20630 frames, score 0, max score 4
# Completed 53 games, 85 rewards, 20838 frames, score 0, max score 4
# Completed 54 games, 87 rewards, 21175 frames, score 1, max score 4
# Completed 55 games, 88 rewards, 21356 frames, score 0, max score 4
# Completed 56 games, 90 rewards, 22018 frames, score 1, max score 4
# Completed 57 games, 91 rewards, 22199 frames, score 0, max score 4
# Completed 58 games, 92 rewards, 22453 frames, score 0, max score 4
# Completed 59 games, 93 rewards, 22707 frames, score 0, max score 4
# Completed 60 games, 94 rewards, 22888 frames, score 0, max score 4
# Completed 61 games, 95 rewards, 23096 frames, score 0, max score 4
# Completed 62 games, 96 rewards, 23350 frames, score 0, max score 4
# Completed 63 games, 98 rewards, 23691 frames, score 1, max score 4
# Completed 64 games, 99 rewards, 23899 frames, score 0, max score 4
# Completed 65 games, 100 rewards, 24153 frames, score 0, max score 4
# Completed 66 games, 101 rewards, 24334 frames, score 0, max score 4
# Completed 67 games, 103 rewards, 24748 frames, score 1, max score 4
# Completed 68 games, 104 rewards, 24956 frames, score 0, max score 4
# Completed 69 games, 105 rewards, 25164 frames, score 0, max score 4
# Completed 70 games, 106 rewards, 25372 frames, score 0, max score 4
# Completed 71 games, 109 rewards, 26194 frames, score 2, max score 4
# Completed 72 games, 110 rewards, 26448 frames, score 0, max score 4
# Completed 73 games, 111 rewards, 26656 frames, score 0, max score 4
# Completed 74 games, 117 rewards, 28908 frames, score 5, max score 5
# Completed 75 games, 118 rewards, 29162 frames, score 0, max score 5
# Completed 76 games, 119 rewards, 29416 frames, score 0, max score 5
# Completed 77 games, 120 rewards, 29597 frames, score 0, max score 5
# Completed 78 games, 121 rewards, 29851 frames, score 0, max score 5
# Completed 79 games, 122 rewards, 30105 frames, score 0, max score 5
# Completed 80 games, 124 rewards, 30492 frames, score 1, max score 5
# Completed 81 games, 127 rewards, 31431 frames, score 2, max score 5
# Completed 82 games, 130 rewards, 32283 frames, score 2, max score 5
# Completed 83 games, 131 rewards, 32537 frames, score 0, max score 5
# Completed 84 games, 132 rewards, 32718 frames, score 0, max score 5
# Completed 85 games, 134 rewards, 33252 frames, score 1, max score 5
# Completed 86 games, 136 rewards, 33740 frames, score 1, max score 5
# Completed 87 games, 137 rewards, 33994 frames, score 0, max score 5
# Completed 88 games, 138 rewards, 34202 frames, score 0, max score 5
# Completed 89 games, 141 rewards, 35102 frames, score 2, max score 5
# Completed 90 games, 142 rewards, 35283 frames, score 0, max score 5
# Completed 91 games, 146 rewards, 37273 frames, score 3, max score 5
# Completed 92 games, 147 rewards, 37527 frames, score 0, max score 5
# Completed 93 games, 148 rewards, 37708 frames, score 0, max score 5
# Completed 94 games, 149 rewards, 37962 frames, score 0, max score 5
# Completed 95 games, 150 rewards, 38216 frames, score 0, max score 5
# Completed 96 games, 151 rewards, 38397 frames, score 0, max score 5
# Completed 97 games, 154 rewards, 38901 frames, score 2, max score 5
# Completed 98 games, 155 rewards, 39109 frames, score 0, max score 5
# Completed 99 games, 156 rewards, 39363 frames, score 0, max score 5
# Completed 100 games, 157 rewards, 39617 frames, score 0, max score 5
# Completed 101 games, 158 rewards, 39798 frames, score 0, max score 5
# Completed 102 games, 159 rewards, 40006 frames, score 0, max score 5
# Completed 103 games, 161 rewards, 40412 frames, score 1, max score 5
# Completed 104 games, 162 rewards, 40620 frames, score 0, max score 5
# Completed 105 games, 164 rewards, 41354 frames, score 1, max score 5
# Completed 106 games, 168 rewards, 42220 frames, score 3, max score 5
# Completed 107 games, 169 rewards, 42428 frames, score 0, max score 5
# Completed 108 games, 170 rewards, 42636 frames, score 0, max score 5
# Completed 109 games, 171 rewards, 42844 frames, score 0, max score 5
# Completed 110 games, 172 rewards, 43025 frames, score 0, max score 5
# Completed 111 games, 174 rewards, 43944 frames, score 1, max score 5
# Completed 112 games, 176 rewards, 44381 frames, score 1, max score 5
# Completed 113 games, 178 rewards, 44795 frames, score 1, max score 5
# Completed 114 games, 179 rewards, 45003 frames, score 0, max score 5
# Completed 115 games, 181 rewards, 45408 frames, score 1, max score 5
# Completed 116 games, 182 rewards, 45662 frames, score 0, max score 5
# Completed 117 games, 183 rewards, 45916 frames, score 0, max score 5
# Completed 118 games, 184 rewards, 46124 frames, score 0, max score 5
# Completed 119 games, 185 rewards, 46332 frames, score 0, max score 5
# Completed 120 games, 186 rewards, 46513 frames, score 0, max score 5
# Completed 121 games, 187 rewards, 46767 frames, score 0, max score 5
# Completed 122 games, 188 rewards, 47021 frames, score 0, max score 5
# Completed 123 games, 189 rewards, 47202 frames, score 0, max score 5
# Completed 124 games, 191 rewards, 47630 frames, score 1, max score 5
# Completed 125 games, 194 rewards, 48447 frames, score 2, max score 5
# Completed 126 games, 195 rewards, 48655 frames, score 0, max score 5
# Completed 127 games, 196 rewards, 48863 frames, score 0, max score 5
# Completed 128 games, 198 rewards, 49246 frames, score 1, max score 5
# Completed 129 games, 202 rewards, 50131 frames, score 3, max score 5
# Completed 130 games, 203 rewards, 50385 frames, score 0, max score 5
# Completed 131 games, 206 rewards, 50996 frames, score 2, max score 5
# Completed 132 games, 207 rewards, 51250 frames, score 0, max score 5
# Completed 133 games, 209 rewards, 51678 frames, score 1, max score 5
# Completed 134 games, 210 rewards, 51859 frames, score 0, max score 5
# Completed 135 games, 211 rewards, 52113 frames, score 0, max score 5
# Completed 136 games, 214 rewards, 52714 frames, score 2, max score 5
# Completed 137 games, 215 rewards, 52968 frames, score 0, max score 5
# Completed 138 games, 216 rewards, 53149 frames, score 0, max score 5
# Completed 139 games, 217 rewards, 53403 frames, score 0, max score 5
# Completed 140 games, 218 rewards, 53657 frames, score 0, max score 5
# Completed 141 games, 219 rewards, 53838 frames, score 0, max score 5
# Completed 142 games, 220 rewards, 54092 frames, score 0, max score 5
# Completed 143 games, 221 rewards, 54300 frames, score 0, max score 5
# Completed 144 games, 222 rewards, 54508 frames, score 0, max score 5
# Completed 145 games, 223 rewards, 54762 frames, score 0, max score 5
# Completed 146 games, 225 rewards, 55233 frames, score 1, max score 5
# Completed 147 games, 227 rewards, 55767 frames, score 1, max score 5
# Completed 148 games, 228 rewards, 55975 frames, score 0, max score 5
# Completed 149 games, 229 rewards, 56183 frames, score 0, max score 5
# Completed 150 games, 231 rewards, 56734 frames, score 1, max score 5
# Completed 151 games, 233 rewards, 57222 frames, score 1, max score 5
# Completed 152 games, 234 rewards, 57476 frames, score 0, max score 5
# Completed 153 games, 235 rewards, 57657 frames, score 0, max score 5
# Completed 154 games, 236 rewards, 57911 frames, score 0, max score 5
# Completed 155 games, 237 rewards, 58165 frames, score 0, max score 5
# Completed 156 games, 238 rewards, 58419 frames, score 0, max score 5
# Completed 157 games, 240 rewards, 58847 frames, score 1, max score 5
# Completed 158 games, 241 rewards, 59055 frames, score 0, max score 5
# Completed 159 games, 242 rewards, 59309 frames, score 0, max score 5
# Completed 160 games, 243 rewards, 59517 frames, score 0, max score 5
# Completed 161 games, 244 rewards, 59771 frames, score 0, max score 5
# Completed 162 games, 245 rewards, 60025 frames, score 0, max score 5
# Completed 163 games, 246 rewards, 60279 frames, score 0, max score 5
# Completed 164 games, 247 rewards, 60533 frames, score 0, max score 5
# Completed 165 games, 251 rewards, 61748 frames, score 3, max score 5
# Completed 166 games, 252 rewards, 61929 frames, score 0, max score 5
# Completed 167 games, 253 rewards, 62183 frames, score 0, max score 5
# Completed 168 games, 254 rewards, 62391 frames, score 0, max score 5
# Completed 169 games, 255 rewards, 62572 frames, score 0, max score 5
# Completed 170 games, 256 rewards, 62826 frames, score 0, max score 5
# Completed 171 games, 257 rewards, 63080 frames, score 0, max score 5
# Completed 172 games, 258 rewards, 63261 frames, score 0, max score 5
# Completed 173 games, 261 rewards, 64150 frames, score 2, max score 5
# Completed 174 games, 262 rewards, 64331 frames, score 0, max score 5
# Completed 175 games, 263 rewards, 64539 frames, score 0, max score 5
# Completed 176 games, 265 rewards, 65273 frames, score 1, max score 5
# Completed 177 games, 267 rewards, 65863 frames, score 1, max score 5
# Completed 178 games, 269 rewards, 66230 frames, score 1, max score 5
# Completed 179 games, 271 rewards, 66718 frames, score 1, max score 5
# Completed 180 games, 272 rewards, 66926 frames, score 0, max score 5
# Completed 181 games, 273 rewards, 67107 frames, score 0, max score 5
# Completed 182 games, 275 rewards, 67619 frames, score 1, max score 5
# Completed 183 games, 276 rewards, 67873 frames, score 0, max score 5
# Completed 184 games, 277 rewards, 68127 frames, score 0, max score 5
# Completed 185 games, 278 rewards, 68381 frames, score 0, max score 5
# Completed 186 games, 279 rewards, 68589 frames, score 0, max score 5
# Completed 187 games, 283 rewards, 69455 frames, score 3, max score 5
# Completed 188 games, 284 rewards, 69636 frames, score 0, max score 5
# Completed 189 games, 286 rewards, 70370 frames, score 1, max score 5
# Completed 190 games, 287 rewards, 70578 frames, score 0, max score 5
# Completed 191 games, 288 rewards, 70786 frames, score 0, max score 5
# Completed 192 games, 289 rewards, 71040 frames, score 0, max score 5
# Completed 193 games, 290 rewards, 71221 frames, score 0, max score 5
# Completed 194 games, 291 rewards, 71475 frames, score 0, max score 5
# Completed 195 games, 296 rewards, 72512 frames, score 4, max score 5
# Completed 196 games, 298 rewards, 72880 frames, score 1, max score 5
# Completed 197 games, 302 rewards, 73885 frames, score 3, max score 5
# Completed 198 games, 303 rewards, 74066 frames, score 0, max score 5
# Completed 199 games, 304 rewards, 74320 frames, score 0, max score 5
# Completed 200 games, 305 rewards, 74574 frames, score 0, max score 5
# Completed 201 games, 306 rewards, 74782 frames, score 0, max score 5
# Completed 202 games, 309 rewards, 75667 frames, score 2, max score 5
# Completed 203 games, 310 rewards, 75848 frames, score 0, max score 5
# Completed 204 games, 313 rewards, 77545 frames, score 2, max score 5
# Completed 205 games, 314 rewards, 77799 frames, score 0, max score 5
# Completed 206 games, 315 rewards, 78007 frames, score 0, max score 5
# Completed 207 games, 317 rewards, 78504 frames, score 1, max score 5
# Completed 208 games, 318 rewards, 78712 frames, score 0, max score 5
# Completed 209 games, 319 rewards, 78893 frames, score 0, max score 5
# Completed 210 games, 320 rewards, 79074 frames, score 0, max score 5
# Completed 211 games, 321 rewards, 79328 frames, score 0, max score 5
# Completed 212 games, 324 rewards, 80055 frames, score 2, max score 5
# Completed 213 games, 325 rewards, 80309 frames, score 0, max score 5
# Completed 214 games, 326 rewards, 80490 frames, score 0, max score 5
# Completed 215 games, 327 rewards, 80671 frames, score 0, max score 5
# Completed 216 games, 328 rewards, 80879 frames, score 0, max score 5
# Completed 217 games, 331 rewards, 81465 frames, score 2, max score 5
# Completed 218 games, 333 rewards, 82221 frames, score 1, max score 5
# Completed 219 games, 334 rewards, 82429 frames, score 0, max score 5
# Completed 220 games, 338 rewards, 83644 frames, score 3, max score 5
# Completed 221 games, 340 rewards, 84156 frames, score 1, max score 5
# Completed 222 games, 341 rewards, 84337 frames, score 0, max score 5
# Completed 223 games, 342 rewards, 84545 frames, score 0, max score 5
# Completed 224 games, 343 rewards, 84726 frames, score 0, max score 5
# Completed 225 games, 345 rewards, 85328 frames, score 1, max score 5
# Completed 226 games, 346 rewards, 85582 frames, score 0, max score 5
# Completed 227 games, 348 rewards, 86002 frames, score 1, max score 5
# Completed 228 games, 349 rewards, 86256 frames, score 0, max score 5
# Completed 229 games, 350 rewards, 86510 frames, score 0, max score 5
# Completed 230 games, 356 rewards, 87724 frames, score 5, max score 5
# Completed 231 games, 359 rewards, 88344 frames, score 2, max score 5
# Completed 232 games, 363 rewards, 89182 frames, score 3, max score 5
# Completed 233 games, 364 rewards, 89363 frames, score 0, max score 5
# Completed 234 games, 365 rewards, 89617 frames, score 0, max score 5
# Completed 235 games, 367 rewards, 90022 frames, score 1, max score 5
# Completed 236 games, 368 rewards, 90203 frames, score 0, max score 5
# Completed 237 games, 371 rewards, 90717 frames, score 2, max score 5
# Completed 238 games, 372 rewards, 90898 frames, score 0, max score 5
# Completed 239 games, 373 rewards, 91152 frames, score 0, max score 5
# Completed 240 games, 375 rewards, 91535 frames, score 1, max score 5
# Completed 241 games, 376 rewards, 91743 frames, score 0, max score 5
# Completed 242 games, 377 rewards, 91924 frames, score 0, max score 5
# Completed 243 games, 380 rewards, 92483 frames, score 2, max score 5
# Completed 244 games, 382 rewards, 93073 frames, score 1, max score 5
# Completed 245 games, 383 rewards, 93254 frames, score 0, max score 5
# Completed 246 games, 384 rewards, 93462 frames, score 0, max score 5
# Completed 247 games, 385 rewards, 93643 frames, score 0, max score 5
# Completed 248 games, 386 rewards, 93824 frames, score 0, max score 5
# Completed 249 games, 387 rewards, 94032 frames, score 0, max score 5
# Completed 250 games, 390 rewards, 94836 frames, score 2, max score 5
# Completed 251 games, 394 rewards, 96439 frames, score 3, max score 5
# Completed 252 games, 395 rewards, 96647 frames, score 0, max score 5
# Completed 253 games, 397 rewards, 97823 frames, score 1, max score 5
# Completed 254 games, 398 rewards, 98004 frames, score 0, max score 5
# Completed 255 games, 399 rewards, 98212 frames, score 0, max score 5
# Completed 256 games, 400 rewards, 98466 frames, score 0, max score 5
# Completed 257 games, 402 rewards, 98844 frames, score 1, max score 5
# Completed 258 games, 403 rewards, 99025 frames, score 0, max score 5
# Completed 259 games, 406 rewards, 99556 frames, score 2, max score 5
# Completed 260 games, 407 rewards, 99737 frames, score 0, max score 5
# Completed 261 games, 408 rewards, 99945 frames, score 0, max score 5
# Completed 262 games, 409 rewards, 100126 frames, score 0, max score 5
# Completed 263 games, 410 rewards, 100307 frames, score 0, max score 5
# Completed 264 games, 412 rewards, 100721 frames, score 1, max score 5
# Completed 265 games, 413 rewards, 100929 frames, score 0, max score 5
# Completed 266 games, 415 rewards, 101417 frames, score 1, max score 5
# Completed 267 games, 417 rewards, 101914 frames, score 1, max score 5
# Completed 268 games, 421 rewards, 102955 frames, score 3, max score 5
# Completed 269 games, 422 rewards, 103136 frames, score 0, max score 5
# Completed 270 games, 423 rewards, 103390 frames, score 0, max score 5
# Completed 271 games, 424 rewards, 103571 frames, score 0, max score 5
# Completed 272 games, 425 rewards, 103752 frames, score 0, max score 5
# Completed 273 games, 426 rewards, 103933 frames, score 0, max score 5
# Completed 274 games, 427 rewards, 104114 frames, score 0, max score 5
# Completed 275 games, 430 rewards, 104702 frames, score 2, max score 5
# Completed 276 games, 431 rewards, 104910 frames, score 0, max score 5
# Completed 277 games, 432 rewards, 105164 frames, score 0, max score 5
# Completed 278 games, 433 rewards, 105345 frames, score 0, max score 5
# Completed 279 games, 434 rewards, 105599 frames, score 0, max score 5
# Completed 280 games, 435 rewards, 105780 frames, score 0, max score 5
# Completed 281 games, 436 rewards, 106034 frames, score 0, max score 5
# Completed 282 games, 437 rewards, 106242 frames, score 0, max score 5
# Completed 283 games, 438 rewards, 106450 frames, score 0, max score 5
# Completed 284 games, 440 rewards, 107323 frames, score 1, max score 5
# Completed 285 games, 441 rewards, 107531 frames, score 0, max score 5
# Completed 286 games, 444 rewards, 108085 frames, score 2, max score 5
# Completed 287 games, 447 rewards, 108605 frames, score 2, max score 5
# Completed 288 games, 449 rewards, 108973 frames, score 1, max score 5
# Completed 289 games, 453 rewards, 109768 frames, score 3, max score 5
# Completed 290 games, 455 rewards, 110182 frames, score 1, max score 5
# Completed 291 games, 459 rewards, 110909 frames, score 3, max score 5
# Completed 292 games, 460 rewards, 111117 frames, score 0, max score 5
# Completed 293 games, 461 rewards, 111371 frames, score 0, max score 5
# Completed 294 games, 464 rewards, 112219 frames, score 2, max score 5
# Completed 295 games, 465 rewards, 112427 frames, score 0, max score 5
# Completed 296 games, 466 rewards, 112681 frames, score 0, max score 5
# Completed 297 games, 467 rewards, 112862 frames, score 0, max score 5
# Completed 298 games, 469 rewards, 113413 frames, score 1, max score 5
# Completed 299 games, 470 rewards, 113667 frames, score 0, max score 5
# Completed 300 games, 471 rewards, 113921 frames, score 0, max score 5
# Completed 301 games, 472 rewards, 114175 frames, score 0, max score 5
# Completed 302 games, 473 rewards, 114356 frames, score 0, max score 5
# Completed 303 games, 475 rewards, 115018 frames, score 1, max score 5
# Completed 304 games, 476 rewards, 115272 frames, score 0, max score 5
# Completed 305 games, 478 rewards, 115784 frames, score 1, max score 5
# Completed 306 games, 479 rewards, 116038 frames, score 0, max score 5
# Completed 307 games, 480 rewards, 116292 frames, score 0, max score 5
# Completed 308 games, 482 rewards, 116724 frames, score 1, max score 5
# Completed 309 games, 483 rewards, 116932 frames, score 0, max score 5
# Completed 310 games, 486 rewards, 117631 frames, score 2, max score 5
# Completed 311 games, 487 rewards, 117839 frames, score 0, max score 5
# Completed 312 games, 488 rewards, 118020 frames, score 0, max score 5
# Completed 313 games, 489 rewards, 118201 frames, score 0, max score 5
# Completed 314 games, 491 rewards, 118752 frames, score 1, max score 5
# Completed 315 games, 492 rewards, 118960 frames, score 0, max score 5
# Completed 316 games, 493 rewards, 119214 frames, score 0, max score 5
# Completed 317 games, 496 rewards, 119791 frames, score 2, max score 5
# Completed 318 games, 497 rewards, 119972 frames, score 0, max score 5
# Completed 319 games, 498 rewards, 120153 frames, score 0, max score 5
# Completed 320 games, 499 rewards, 120361 frames, score 0, max score 5
# The number of games played was 322
# The number of rewards was 500
# The size of each returned Q-matrix was (4000, 3)

# %% [markdown]
# The returned value of `q_states` is a list of 4000x3 numpy arrays (20 states, 3 actions).  The list contains `m_rewards` of these. We want to convert it into something that matplotlib can plot.

# %%
import numpy as np

Q = np.array([np.reshape(q,-1) for q in q_states])
print('Q is now of shape',Q.shape)
print('the max absolute value of Q is ',np.amax(abs(Q)))
# Out:
# Q is now of shape (500, 12000)
# the max absolute value of Q is  1.4195881519569922

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(14,6),layout='tight')
ax = [ fig.add_subplot(2,1,x) for x in range(1,3) ]
ax[0].plot(np.arange(0,len(q_states)),Q)
ax[0].set_title('Q values of all states')
ax[1].plot(np.arange(0,len(q_states)),q_achieved)
ax[1].set_title('Q values of state achieved at each time')
ax[1].set_ylabel('Reward number')
# Out:
# Text(0, 0.5, 'Reward number')

# %% [markdown]
# OK, now let's try running it for a much longer period -- say, 5000 complete games.  We won't ask it to print out any states this time.

# %%
scores, q_achieved, q_states = pong_game.run(m_games=5000, states=[])

print('The number of games played was',len(scores))
print('The number of video frames was',len(q_states))
print('The size of each returned Q-matrix was',q_states[0].shape)
# Out:
# Completed 0 games, 1 rewards, 182 frames, score 1, max score 5
# Completed 1 games, 2 rewards, 363 frames, score 0, max score 5
# Completed 2 games, 3 rewards, 571 frames, score 0, max score 5
# Completed 3 games, 5 rewards, 1173 frames, score 1, max score 5
# Completed 4 games, 7 rewards, 1678 frames, score 1, max score 5
# Completed 5 games, 8 rewards, 1932 frames, score 0, max score 5
# Completed 6 games, 9 rewards, 2113 frames, score 0, max score 5
# Completed 7 games, 12 rewards, 2760 frames, score 2, max score 5
# Completed 8 games, 14 rewards, 3143 frames, score 1, max score 5
# Completed 9 games, 15 rewards, 3324 frames, score 0, max score 5
# Completed 10 games, 16 rewards, 3505 frames, score 0, max score 5
# Completed 11 games, 17 rewards, 3713 frames, score 0, max score 5
# Completed 12 games, 21 rewards, 4509 frames, score 3, max score 5
# Completed 13 games, 23 rewards, 4876 frames, score 1, max score 5
# Completed 14 games, 25 rewards, 5320 frames, score 1, max score 5
# Completed 15 games, 26 rewards, 5528 frames, score 0, max score 5
# Completed 16 games, 27 rewards, 5782 frames, score 0, max score 5
# Completed 17 games, 28 rewards, 5990 frames, score 0, max score 5
# Completed 18 games, 29 rewards, 6171 frames, score 0, max score 5
# Completed 19 games, 32 rewards, 7343 frames, score 2, max score 5
# Completed 20 games, 33 rewards, 7524 frames, score 0, max score 5
# Completed 21 games, 34 rewards, 7732 frames, score 0, max score 5
# Completed 22 games, 35 rewards, 7986 frames, score 0, max score 5
# Completed 23 games, 36 rewards, 8167 frames, score 0, max score 5
# Completed 24 games, 37 rewards, 8348 frames, score 0, max score 5
# Completed 25 games, 38 rewards, 8602 frames, score 0, max score 5
# Completed 26 games, 39 rewards, 8856 frames, score 0, max score 5
# Completed 27 games, 41 rewards, 9518 frames, score 1, max score 5
# Completed 28 games, 42 rewards, 9772 frames, score 0, max score 5
# Completed 29 games, 43 rewards, 10026 frames, score 0, max score 5
# Completed 30 games, 44 rewards, 10234 frames, score 0, max score 5
# Completed 31 games, 45 rewards, 10488 frames, score 0, max score 5
# Completed 32 games, 47 rewards, 10894 frames, score 1, max score 5
# Completed 33 games, 48 rewards, 11075 frames, score 0, max score 5
# Completed 34 games, 49 rewards, 11256 frames, score 0, max score 5
# Completed 35 games, 51 rewards, 11934 frames, score 1, max score 5
# Completed 36 games, 53 rewards, 12485 frames, score 1, max score 5
# Completed 37 games, 54 rewards, 12739 frames, score 0, max score 5
# Completed 38 games, 55 rewards, 12920 frames, score 0, max score 5
# Completed 39 games, 56 rewards, 13174 frames, score 0, max score 5
# Completed 40 games, 57 rewards, 13382 frames, score 0, max score 5
# Completed 41 games, 60 rewards, 13934 frames, score 2, max score 5
# Completed 42 games, 61 rewards, 14142 frames, score 0, max score 5
# Completed 43 games, 64 rewards, 14812 frames, score 2, max score 5
# Completed 44 games, 70 rewards, 15911 frames, score 5, max score 5
# Completed 45 games, 71 rewards, 16092 frames, score 0, max score 5
# Completed 46 games, 73 rewards, 16724 frames, score 1, max score 5
# Completed 47 games, 75 rewards, 17207 frames, score 1, max score 5
# Completed 48 games, 77 rewards, 17719 frames, score 1, max score 5
# Completed 49 games, 79 rewards, 18087 frames, score 1, max score 5
# Completed 50 games, 82 rewards, 18904 frames, score 2, max score 5
# Completed 51 games, 83 rewards, 19112 frames, score 0, max score 5
# Completed 52 games, 86 rewards, 19722 frames, score 2, max score 5
# Completed 53 games, 87 rewards, 19976 frames, score 0, max score 5
# Completed 54 games, 88 rewards, 20184 frames, score 0, max score 5
# Completed 55 games, 89 rewards, 20392 frames, score 0, max score 5
# Completed 56 games, 90 rewards, 20600 frames, score 0, max score 5
# Completed 57 games, 91 rewards, 20854 frames, score 0, max score 5
# Completed 58 games, 92 rewards, 21035 frames, score 0, max score 5
# Completed 59 games, 94 rewards, 21472 frames, score 1, max score 5
# Completed 60 games, 96 rewards, 21813 frames, score 1, max score 5
# Completed 61 games, 97 rewards, 22067 frames, score 0, max score 5
# Completed 62 games, 98 rewards, 22248 frames, score 0, max score 5
# Completed 63 games, 99 rewards, 22502 frames, score 0, max score 5
# Completed 64 games, 100 rewards, 22683 frames, score 0, max score 5
# Completed 65 games, 101 rewards, 22891 frames, score 0, max score 5
# Completed 66 games, 103 rewards, 23328 frames, score 1, max score 5
# Completed 67 games, 104 rewards, 23582 frames, score 0, max score 5
# Completed 68 games, 106 rewards, 24116 frames, score 1, max score 5
# Completed 69 games, 107 rewards, 24370 frames, score 0, max score 5
# Completed 70 games, 108 rewards, 24624 frames, score 0, max score 5
# Completed 71 games, 109 rewards, 24832 frames, score 0, max score 5
# Completed 72 games, 110 rewards, 25040 frames, score 0, max score 5
# Completed 73 games, 111 rewards, 25221 frames, score 0, max score 5
# Completed 74 games, 113 rewards, 25562 frames, score 1, max score 5
# Completed 75 games, 114 rewards, 25770 frames, score 0, max score 5
# Completed 76 games, 115 rewards, 25978 frames, score 0, max score 5
# Completed 77 games, 116 rewards, 26186 frames, score 0, max score 5
# Completed 78 games, 118 rewards, 27105 frames, score 1, max score 5
# Completed 79 games, 119 rewards, 27359 frames, score 0, max score 5
# Completed 80 games, 121 rewards, 27713 frames, score 1, max score 5
# Completed 81 games, 122 rewards, 27894 frames, score 0, max score 5
# Completed 82 games, 123 rewards, 28102 frames, score 0, max score 5
# Completed 83 games, 124 rewards, 28283 frames, score 0, max score 5
# Completed 84 games, 125 rewards, 28491 frames, score 0, max score 5
# Completed 85 games, 128 rewards, 28930 frames, score 2, max score 5
# Completed 86 games, 131 rewards, 29730 frames, score 2, max score 5
# Completed 87 games, 132 rewards, 29984 frames, score 0, max score 5
# Completed 88 games, 133 rewards, 30192 frames, score 0, max score 5
# Completed 89 games, 134 rewards, 30400 frames, score 0, max score 5
# Completed 90 games, 136 rewards, 31078 frames, score 1, max score 5
# Completed 91 games, 143 rewards, 32127 frames, score 6, max score 6
# Completed 92 games, 144 rewards, 32335 frames, score 0, max score 6
# Completed 93 games, 145 rewards, 32516 frames, score 0, max score 6
# Completed 94 games, 146 rewards, 32724 frames, score 0, max score 6
# Completed 95 games, 148 rewards, 33275 frames, score 1, max score 6
# Completed 96 games, 149 rewards, 33529 frames, score 0, max score 6
# Completed 97 games, 150 rewards, 33710 frames, score 0, max score 6
# Completed 98 games, 152 rewards, 34078 frames, score 1, max score 6
# Completed 99 games, 154 rewards, 34483 frames, score 1, max score 6
# Completed 100 games, 156 rewards, 34889 frames, score 1, max score 6
# Completed 101 games, 158 rewards, 35272 frames, score 1, max score 6
# Completed 102 games, 161 rewards, 35946 frames, score 2, max score 6
# Completed 103 games, 162 rewards, 36127 frames, score 0, max score 6
# Completed 104 games, 163 rewards, 36308 frames, score 0, max score 6
# Completed 105 games, 164 rewards, 36489 frames, score 0, max score 6
# Completed 106 games, 165 rewards, 36697 frames, score 0, max score 6
# Completed 107 games, 166 rewards, 36951 frames, score 0, max score 6
# Completed 108 games, 168 rewards, 37411 frames, score 1, max score 6
# Completed 109 games, 170 rewards, 38073 frames, score 1, max score 6
# Completed 110 games, 172 rewards, 38487 frames, score 1, max score 6
# Completed 111 games, 173 rewards, 38668 frames, score 0, max score 6
# Completed 112 games, 174 rewards, 38876 frames, score 0, max score 6
# Completed 113 games, 176 rewards, 39244 frames, score 1, max score 6
# Completed 114 games, 177 rewards, 39425 frames, score 0, max score 6
# Completed 115 games, 179 rewards, 39885 frames, score 1, max score 6
# Completed 116 games, 181 rewards, 40290 frames, score 1, max score 6
# Completed 117 games, 183 rewards, 40866 frames, score 1, max score 6
# Completed 118 games, 185 rewards, 41218 frames, score 1, max score 6
# Completed 119 games, 189 rewards, 42037 frames, score 3, max score 6
# Completed 120 games, 190 rewards, 42245 frames, score 0, max score 6
# Completed 121 games, 191 rewards, 42426 frames, score 0, max score 6
# Completed 122 games, 192 rewards, 42607 frames, score 0, max score 6
# Completed 123 games, 193 rewards, 42861 frames, score 0, max score 6
# Completed 124 games, 194 rewards, 43115 frames, score 0, max score 6
# Completed 125 games, 195 rewards, 43369 frames, score 0, max score 6
# Completed 126 games, 197 rewards, 44103 frames, score 1, max score 6
# Completed 127 games, 198 rewards, 44311 frames, score 0, max score 6
# Completed 128 games, 199 rewards, 44519 frames, score 0, max score 6
# Completed 129 games, 200 rewards, 44727 frames, score 0, max score 6
# Completed 130 games, 202 rewards, 45125 frames, score 1, max score 6
# Completed 131 games, 203 rewards, 45379 frames, score 0, max score 6
# Completed 132 games, 205 rewards, 45793 frames, score 1, max score 6
# Completed 133 games, 206 rewards, 46047 frames, score 0, max score 6
# Completed 134 games, 208 rewards, 46475 frames, score 1, max score 6
# Completed 135 games, 211 rewards, 47018 frames, score 2, max score 6
# Completed 136 games, 213 rewards, 47569 frames, score 1, max score 6
# Completed 137 games, 214 rewards, 47823 frames, score 0, max score 6
# Completed 138 games, 215 rewards, 48004 frames, score 0, max score 6
# Completed 139 games, 216 rewards, 48185 frames, score 0, max score 6
# Completed 140 games, 217 rewards, 48439 frames, score 0, max score 6
# Completed 141 games, 219 rewards, 48902 frames, score 1, max score 6
# Completed 142 games, 221 rewards, 49399 frames, score 1, max score 6
# Completed 143 games, 222 rewards, 49580 frames, score 0, max score 6
# Completed 144 games, 224 rewards, 49932 frames, score 1, max score 6
# Completed 145 games, 225 rewards, 50140 frames, score 0, max score 6
# Completed 146 games, 226 rewards, 50394 frames, score 0, max score 6
# Completed 147 games, 228 rewards, 50800 frames, score 1, max score 6
# Completed 148 games, 229 rewards, 51008 frames, score 0, max score 6
# Completed 149 games, 232 rewards, 51602 frames, score 2, max score 6
# Completed 150 games, 233 rewards, 51783 frames, score 0, max score 6
# Completed 151 games, 234 rewards, 51964 frames, score 0, max score 6
# Completed 152 games, 236 rewards, 52427 frames, score 1, max score 6
# Completed 153 games, 238 rewards, 52768 frames, score 1, max score 6
# Completed 154 games, 239 rewards, 52949 frames, score 0, max score 6
# Completed 155 games, 241 rewards, 53525 frames, score 1, max score 6
# Completed 156 games, 242 rewards, 53779 frames, score 0, max score 6
# Completed 157 games, 246 rewards, 54462 frames, score 3, max score 6
# Completed 158 games, 248 rewards, 54922 frames, score 1, max score 6
# Completed 159 games, 251 rewards, 55589 frames, score 2, max score 6
# Completed 160 games, 253 rewards, 56251 frames, score 1, max score 6
# Completed 161 games, 254 rewards, 56505 frames, score 0, max score 6
# Completed 162 games, 255 rewards, 56759 frames, score 0, max score 6
# Completed 163 games, 256 rewards, 57013 frames, score 0, max score 6
# Completed 164 games, 257 rewards, 57194 frames, score 0, max score 6
# Completed 165 games, 258 rewards, 57375 frames, score 0, max score 6
# Completed 166 games, 259 rewards, 57629 frames, score 0, max score 6
# Completed 167 games, 261 rewards, 57997 frames, score 1, max score 6
# Completed 168 games, 262 rewards, 58178 frames, score 0, max score 6
# Completed 169 games, 263 rewards, 58386 frames, score 0, max score 6
# Completed 170 games, 264 rewards, 58567 frames, score 0, max score 6
# Completed 171 games, 266 rewards, 59118 frames, score 1, max score 6
# Completed 172 games, 267 rewards, 59372 frames, score 0, max score 6
# Completed 173 games, 269 rewards, 59835 frames, score 1, max score 6
# Completed 174 games, 273 rewards, 60655 frames, score 3, max score 6
# Completed 175 games, 274 rewards, 60909 frames, score 0, max score 6
# Completed 176 games, 275 rewards, 61117 frames, score 0, max score 6
# Completed 177 games, 276 rewards, 61298 frames, score 0, max score 6
# Completed 178 games, 279 rewards, 61877 frames, score 2, max score 6
# Completed 179 games, 280 rewards, 62131 frames, score 0, max score 6
# Completed 180 games, 281 rewards, 62385 frames, score 0, max score 6
# Completed 181 games, 282 rewards, 62566 frames, score 0, max score 6
# Completed 182 games, 284 rewards, 63029 frames, score 1, max score 6
# Completed 183 games, 285 rewards, 63210 frames, score 0, max score 6
# Completed 184 games, 286 rewards, 63391 frames, score 0, max score 6
# Completed 185 games, 287 rewards, 63645 frames, score 0, max score 6
# Completed 186 games, 289 rewards, 64564 frames, score 1, max score 6
# Completed 187 games, 290 rewards, 64745 frames, score 0, max score 6
# Completed 188 games, 291 rewards, 64926 frames, score 0, max score 6
# Completed 189 games, 292 rewards, 65107 frames, score 0, max score 6
# Completed 190 games, 294 rewards, 65513 frames, score 1, max score 6
# Completed 191 games, 296 rewards, 66269 frames, score 1, max score 6
# Completed 192 games, 298 rewards, 66678 frames, score 1, max score 6
# Completed 193 games, 300 rewards, 67254 frames, score 1, max score 6
# Completed 194 games, 302 rewards, 67668 frames, score 1, max score 6
# Completed 195 games, 303 rewards, 67876 frames, score 0, max score 6
# Completed 196 games, 305 rewards, 68427 frames, score 1, max score 6
# Completed 197 games, 307 rewards, 68832 frames, score 1, max score 6
# Completed 198 games, 308 rewards, 69086 frames, score 0, max score 6
# Completed 199 games, 309 rewards, 69267 frames, score 0, max score 6
# Completed 200 games, 313 rewards, 70059 frames, score 3, max score 6
# Completed 201 games, 314 rewards, 70267 frames, score 0, max score 6
# Completed 202 games, 318 rewards, 71109 frames, score 3, max score 6
# Completed 203 games, 319 rewards, 71290 frames, score 0, max score 6
# Completed 204 games, 320 rewards, 71498 frames, score 0, max score 6
# Completed 205 games, 322 rewards, 72176 frames, score 1, max score 6
# Completed 206 games, 324 rewards, 72910 frames, score 1, max score 6
# Completed 207 games, 326 rewards, 73293 frames, score 1, max score 6
# Completed 208 games, 328 rewards, 73798 frames, score 1, max score 6
# Completed 209 games, 329 rewards, 74006 frames, score 0, max score 6
# Completed 210 games, 334 rewards, 75251 frames, score 4, max score 6
# Completed 211 games, 335 rewards, 75505 frames, score 0, max score 6
# Completed 212 games, 336 rewards, 75686 frames, score 0, max score 6
# Completed 213 games, 338 rewards, 76276 frames, score 1, max score 6
# Completed 214 games, 339 rewards, 76484 frames, score 0, max score 6
# Completed 215 games, 340 rewards, 76665 frames, score 0, max score 6
# Completed 216 games, 343 rewards, 77604 frames, score 2, max score 6
# Completed 217 games, 345 rewards, 78155 frames, score 1, max score 6
# Completed 218 games, 348 rewards, 79019 frames, score 2, max score 6
# Completed 219 games, 350 rewards, 79453 frames, score 1, max score 6
# Completed 220 games, 353 rewards, 79795 frames, score 2, max score 6
# Completed 221 games, 358 rewards, 80760 frames, score 4, max score 6
# Completed 222 games, 360 rewards, 81158 frames, score 1, max score 6
# Completed 223 games, 361 rewards, 81366 frames, score 0, max score 6
# Completed 224 games, 364 rewards, 83068 frames, score 2, max score 6
# Completed 225 games, 368 rewards, 84245 frames, score 3, max score 6
# Completed 226 games, 369 rewards, 84499 frames, score 0, max score 6
# Completed 227 games, 370 rewards, 84707 frames, score 0, max score 6
# Completed 228 games, 372 rewards, 85626 frames, score 1, max score 6
# Completed 229 games, 373 rewards, 85834 frames, score 0, max score 6
# Completed 230 games, 376 rewards, 86562 frames, score 2, max score 6
# Completed 231 games, 377 rewards, 86770 frames, score 0, max score 6
# Completed 232 games, 378 rewards, 86978 frames, score 0, max score 6
# Completed 233 games, 379 rewards, 87186 frames, score 0, max score 6
# Completed 234 games, 380 rewards, 87367 frames, score 0, max score 6
# Completed 235 games, 381 rewards, 87621 frames, score 0, max score 6
# Completed 236 games, 383 rewards, 88237 frames, score 1, max score 6
# Completed 237 games, 384 rewards, 88491 frames, score 0, max score 6
# Completed 238 games, 387 rewards, 89175 frames, score 2, max score 6
# Completed 239 games, 389 rewards, 89542 frames, score 1, max score 6
# Completed 240 games, 390 rewards, 89796 frames, score 0, max score 6
# Completed 241 games, 391 rewards, 90004 frames, score 0, max score 6
# Completed 242 games, 393 rewards, 90538 frames, score 1, max score 6
# Completed 243 games, 394 rewards, 90719 frames, score 0, max score 6
# Completed 244 games, 399 rewards, 92295 frames, score 4, max score 6
# Completed 245 games, 401 rewards, 92846 frames, score 1, max score 6
# Completed 246 games, 402 rewards, 93100 frames, score 0, max score 6
# Completed 247 games, 404 rewards, 93483 frames, score 1, max score 6
# Completed 248 games, 405 rewards, 93664 frames, score 0, max score 6
# Completed 249 games, 406 rewards, 93918 frames, score 0, max score 6
# Completed 250 games, 407 rewards, 94126 frames, score 0, max score 6
# Completed 251 games, 410 rewards, 94788 frames, score 2, max score 6
# Completed 252 games, 411 rewards, 94996 frames, score 0, max score 6
# Completed 253 games, 412 rewards, 95204 frames, score 0, max score 6
# Completed 254 games, 413 rewards, 95458 frames, score 0, max score 6
# Completed 255 games, 416 rewards, 95938 frames, score 2, max score 6
# Completed 256 games, 417 rewards, 96192 frames, score 0, max score 6
# Completed 257 games, 420 rewards, 97066 frames, score 2, max score 6
# Completed 258 games, 421 rewards, 97247 frames, score 0, max score 6
# Completed 259 games, 422 rewards, 97501 frames, score 0, max score 6
# Completed 260 games, 423 rewards, 97682 frames, score 0, max score 6
# Completed 261 games, 428 rewards, 98918 frames, score 4, max score 6
# Completed 262 games, 429 rewards, 99126 frames, score 0, max score 6
# Completed 263 games, 430 rewards, 99334 frames, score 0, max score 6
# Completed 264 games, 432 rewards, 99732 frames, score 1, max score 6
# Completed 265 games, 433 rewards, 99940 frames, score 0, max score 6
# Completed 266 games, 434 rewards, 100121 frames, score 0, max score 6
# Completed 267 games, 438 rewards, 100971 frames, score 3, max score 6
# Completed 268 games, 439 rewards, 101225 frames, score 0, max score 6
# Completed 269 games, 440 rewards, 101433 frames, score 0, max score 6
# Completed 270 games, 441 rewards, 101687 frames, score 0, max score 6
# Completed 271 games, 442 rewards, 101941 frames, score 0, max score 6
# Completed 272 games, 443 rewards, 102122 frames, score 0, max score 6
# Completed 273 games, 444 rewards, 102376 frames, score 0, max score 6
# Completed 274 games, 446 rewards, 102839 frames, score 1, max score 6
# Completed 275 games, 447 rewards, 103093 frames, score 0, max score 6
# Completed 276 games, 448 rewards, 103301 frames, score 0, max score 6
# Completed 277 games, 450 rewards, 104174 frames, score 1, max score 6
# Completed 278 games, 452 rewards, 104579 frames, score 1, max score 6
# Completed 279 games, 456 rewards, 105426 frames, score 3, max score 6
# Completed 280 games, 457 rewards, 105634 frames, score 0, max score 6
# Completed 281 games, 461 rewards, 106697 frames, score 3, max score 6
# Completed 282 games, 463 rewards, 107103 frames, score 1, max score 6
# Completed 283 games, 464 rewards, 107284 frames, score 0, max score 6
# Completed 284 games, 467 rewards, 107905 frames, score 2, max score 6
# Completed 285 games, 472 rewards, 109036 frames, score 4, max score 6
# Completed 286 games, 476 rewards, 109933 frames, score 3, max score 6
# Completed 287 games, 478 rewards, 110595 frames, score 1, max score 6
# Completed 288 games, 481 rewards, 111193 frames, score 2, max score 6
# Completed 289 games, 483 rewards, 111656 frames, score 1, max score 6
# Completed 290 games, 486 rewards, 112985 frames, score 2, max score 6
# Completed 291 games, 488 rewards, 113422 frames, score 1, max score 6
# Completed 292 games, 491 rewards, 113999 frames, score 2, max score 6
# Completed 293 games, 493 rewards, 114340 frames, score 1, max score 6
# Completed 294 games, 497 rewards, 115224 frames, score 3, max score 6
# Completed 295 games, 499 rewards, 115591 frames, score 1, max score 6
# Completed 296 games, 500 rewards, 115772 frames, score 0, max score 6
# Completed 297 games, 501 rewards, 115953 frames, score 0, max score 6
# Completed 298 games, 503 rewards, 116413 frames, score 1, max score 6
# Completed 299 games, 504 rewards, 116594 frames, score 0, max score 6
# Completed 300 games, 505 rewards, 116775 frames, score 0, max score 6
# Completed 301 games, 507 rewards, 117531 frames, score 1, max score 6
# Completed 302 games, 509 rewards, 117991 frames, score 1, max score 6
# Completed 303 games, 510 rewards, 118245 frames, score 0, max score 6
# Completed 304 games, 512 rewards, 118612 frames, score 1, max score 6
# Completed 305 games, 514 rewards, 119531 frames, score 1, max score 6
# Completed 306 games, 517 rewards, 120390 frames, score 2, max score 6
# Completed 307 games, 519 rewards, 120850 frames, score 1, max score 6
# Completed 308 games, 526 rewards, 122440 frames, score 6, max score 6
# Completed 309 games, 528 rewards, 123030 frames, score 1, max score 6
# Completed 310 games, 533 rewards, 124304 frames, score 4, max score 6
# Completed 311 games, 534 rewards, 124558 frames, score 0, max score 6
# Completed 312 games, 535 rewards, 124739 frames, score 0, max score 6
# Completed 313 games, 540 rewards, 126032 frames, score 4, max score 6
# Completed 314 games, 542 rewards, 126397 frames, score 1, max score 6
# Completed 315 games, 548 rewards, 127355 frames, score 5, max score 6
# Completed 316 games, 549 rewards, 127536 frames, score 0, max score 6
# Completed 317 games, 556 rewards, 130668 frames, score 6, max score 6
# Completed 318 games, 558 rewards, 131424 frames, score 1, max score 6
# Completed 319 games, 559 rewards, 131605 frames, score 0, max score 6
# Completed 320 games, 561 rewards, 132019 frames, score 1, max score 6
# Completed 321 games, 562 rewards, 132200 frames, score 0, max score 6
# Completed 322 games, 568 rewards, 134559 frames, score 5, max score 6
# Completed 323 games, 572 rewards, 135890 frames, score 3, max score 6
# Completed 324 games, 577 rewards, 136836 frames, score 4, max score 6
# Completed 325 games, 579 rewards, 137214 frames, score 1, max score 6
# Completed 326 games, 583 rewards, 138195 frames, score 3, max score 6
# Completed 327 games, 584 rewards, 138403 frames, score 0, max score 6
# Completed 328 games, 586 rewards, 138801 frames, score 1, max score 6
# Completed 329 games, 590 rewards, 141261 frames, score 3, max score 6
# Completed 330 games, 592 rewards, 141995 frames, score 1, max score 6
# Completed 331 games, 594 rewards, 142529 frames, score 1, max score 6
# Completed 332 games, 596 rewards, 142963 frames, score 1, max score 6
# Completed 333 games, 597 rewards, 143144 frames, score 0, max score 6
# Completed 334 games, 601 rewards, 143952 frames, score 3, max score 6
# Completed 335 games, 602 rewards, 144160 frames, score 0, max score 6
# Completed 336 games, 604 rewards, 144694 frames, score 1, max score 6
# Completed 337 games, 606 rewards, 145660 frames, score 1, max score 6
# Completed 338 games, 607 rewards, 145868 frames, score 0, max score 6
# Completed 339 games, 609 rewards, 146602 frames, score 1, max score 6
# Completed 340 games, 610 rewards, 146810 frames, score 0, max score 6
# Completed 341 games, 612 rewards, 147162 frames, score 1, max score 6
# Completed 342 games, 618 rewards, 149262 frames, score 5, max score 6
# Completed 343 games, 620 rewards, 149759 frames, score 1, max score 6
# Completed 344 games, 625 rewards, 151639 frames, score 4, max score 6
# Completed 345 games, 626 rewards, 151847 frames, score 0, max score 6
# Completed 346 games, 629 rewards, 152498 frames, score 2, max score 6
# Completed 347 games, 632 rewards, 152936 frames, score 2, max score 6
# Completed 348 games, 636 rewards, 153730 frames, score 3, max score 6
# Completed 349 games, 640 rewards, 154662 frames, score 3, max score 6
# Completed 350 games, 642 rewards, 155159 frames, score 1, max score 6
# Completed 351 games, 643 rewards, 155340 frames, score 0, max score 6
# Completed 352 games, 649 rewards, 156436 frames, score 5, max score 6
# Completed 353 games, 650 rewards, 156644 frames, score 0, max score 6
# Completed 354 games, 656 rewards, 157844 frames, score 5, max score 6
# Completed 355 games, 661 rewards, 161737 frames, score 4, max score 6
# Completed 356 games, 662 rewards, 161945 frames, score 0, max score 6
# Completed 357 games, 672 rewards, 165637 frames, score 9, max score 9
# Completed 358 games, 674 rewards, 166065 frames, score 1, max score 9
# Completed 359 games, 677 rewards, 166735 frames, score 2, max score 9
# Completed 360 games, 681 rewards, 167673 frames, score 3, max score 9
# Completed 361 games, 682 rewards, 167854 frames, score 0, max score 9
# Completed 362 games, 685 rewards, 168519 frames, score 2, max score 9
# Completed 363 games, 686 rewards, 168727 frames, score 0, max score 9
# Completed 364 games, 689 rewards, 169266 frames, score 2, max score 9
# Completed 365 games, 690 rewards, 169447 frames, score 0, max score 9
# Completed 366 games, 693 rewards, 169982 frames, score 2, max score 9
# Completed 367 games, 695 rewards, 170365 frames, score 1, max score 9
# Completed 368 games, 697 rewards, 170848 frames, score 1, max score 9
# Completed 369 games, 699 rewards, 171311 frames, score 1, max score 9
# Completed 370 games, 701 rewards, 171678 frames, score 1, max score 9
# Completed 371 games, 702 rewards, 171859 frames, score 0, max score 9
# Completed 372 games, 703 rewards, 172113 frames, score 0, max score 9
# Completed 373 games, 704 rewards, 172321 frames, score 0, max score 9
# Completed 374 games, 706 rewards, 172818 frames, score 1, max score 9
# Completed 375 games, 708 rewards, 173159 frames, score 1, max score 9
# Completed 376 games, 711 rewards, 174061 frames, score 2, max score 9
# Completed 377 games, 713 rewards, 174561 frames, score 1, max score 9
# Completed 378 games, 714 rewards, 174742 frames, score 0, max score 9
# Completed 379 games, 716 rewards, 175148 frames, score 1, max score 9
# Completed 380 games, 718 rewards, 175631 frames, score 1, max score 9
# Completed 381 games, 722 rewards, 176657 frames, score 3, max score 9
# Completed 382 games, 726 rewards, 177305 frames, score 3, max score 9
# Completed 383 games, 728 rewards, 177711 frames, score 1, max score 9
# Completed 384 games, 729 rewards, 177892 frames, score 0, max score 9
# Completed 385 games, 732 rewards, 178494 frames, score 2, max score 9
# Completed 386 games, 734 rewards, 179045 frames, score 1, max score 9
# Completed 387 games, 736 rewards, 179508 frames, score 1, max score 9
# Completed 388 games, 741 rewards, 181640 frames, score 4, max score 9
# Completed 389 games, 742 rewards, 181848 frames, score 0, max score 9
# Completed 390 games, 746 rewards, 182789 frames, score 3, max score 9
# Completed 391 games, 748 rewards, 183379 frames, score 1, max score 9
# Completed 392 games, 749 rewards, 183560 frames, score 0, max score 9
# Completed 393 games, 750 rewards, 183741 frames, score 0, max score 9
# Completed 394 games, 751 rewards, 183949 frames, score 0, max score 9
# Completed 395 games, 752 rewards, 184203 frames, score 0, max score 9
# Completed 396 games, 753 rewards, 184411 frames, score 0, max score 9
# Completed 397 games, 755 rewards, 184778 frames, score 1, max score 9
# Completed 398 games, 758 rewards, 185544 frames, score 2, max score 9
# Completed 399 games, 761 rewards, 186195 frames, score 2, max score 9
# Completed 400 games, 763 rewards, 186658 frames, score 1, max score 9
# Completed 401 games, 767 rewards, 187674 frames, score 3, max score 9
# Completed 402 games, 771 rewards, 188309 frames, score 3, max score 9
# Completed 403 games, 774 rewards, 189335 frames, score 2, max score 9
# Completed 404 games, 775 rewards, 189516 frames, score 0, max score 9
# Completed 405 games, 776 rewards, 189697 frames, score 0, max score 9
# Completed 406 games, 778 rewards, 190103 frames, score 1, max score 9
# Completed 407 games, 780 rewards, 190490 frames, score 1, max score 9
# Completed 408 games, 781 rewards, 190671 frames, score 0, max score 9
# Completed 409 games, 782 rewards, 190925 frames, score 0, max score 9
# Completed 410 games, 783 rewards, 191179 frames, score 0, max score 9
# Completed 411 games, 784 rewards, 191360 frames, score 0, max score 9
# Completed 412 games, 785 rewards, 191568 frames, score 0, max score 9
# Completed 413 games, 786 rewards, 191749 frames, score 0, max score 9
# Completed 414 games, 787 rewards, 191930 frames, score 0, max score 9
# Completed 415 games, 791 rewards, 192988 frames, score 3, max score 9
# Completed 416 games, 792 rewards, 193169 frames, score 0, max score 9
# Completed 417 games, 794 rewards, 193720 frames, score 1, max score 9
# Completed 418 games, 795 rewards, 193974 frames, score 0, max score 9
# Completed 419 games, 799 rewards, 194653 frames, score 3, max score 9
# Completed 420 games, 800 rewards, 194834 frames, score 0, max score 9
# Completed 421 games, 802 rewards, 195342 frames, score 1, max score 9
# Completed 422 games, 807 rewards, 196176 frames, score 4, max score 9
# Completed 423 games, 810 rewards, 196844 frames, score 2, max score 9
# Completed 424 games, 812 rewards, 197242 frames, score 1, max score 9
# Completed 425 games, 813 rewards, 197423 frames, score 0, max score 9
# Completed 426 games, 814 rewards, 197677 frames, score 0, max score 9
# Completed 427 games, 816 rewards, 198174 frames, score 1, max score 9
# Completed 428 games, 817 rewards, 198382 frames, score 0, max score 9
# Completed 429 games, 818 rewards, 198590 frames, score 0, max score 9
# Completed 430 games, 820 rewards, 199004 frames, score 1, max score 9
# Completed 431 games, 823 rewards, 199615 frames, score 2, max score 9
# Completed 432 games, 832 rewards, 201208 frames, score 8, max score 9
# Completed 433 games, 833 rewards, 201462 frames, score 0, max score 9
# Completed 434 games, 836 rewards, 201974 frames, score 2, max score 9
# Completed 435 games, 837 rewards, 202182 frames, score 0, max score 9
# Completed 436 games, 839 rewards, 202580 frames, score 1, max score 9
# Completed 437 games, 841 rewards, 203058 frames, score 1, max score 9
# Completed 438 games, 843 rewards, 203456 frames, score 1, max score 9
# Completed 439 games, 845 rewards, 203808 frames, score 1, max score 9
# Completed 440 games, 847 rewards, 204186 frames, score 1, max score 9
# Completed 441 games, 848 rewards, 204440 frames, score 0, max score 9
# Completed 442 games, 851 rewards, 205366 frames, score 2, max score 9
# Completed 443 games, 852 rewards, 205547 frames, score 0, max score 9
# Completed 444 games, 855 rewards, 206111 frames, score 2, max score 9
# Completed 445 games, 859 rewards, 206786 frames, score 3, max score 9
# Completed 446 games, 862 rewards, 207958 frames, score 2, max score 9
# Completed 447 games, 863 rewards, 208139 frames, score 0, max score 9
# Completed 448 games, 864 rewards, 208320 frames, score 0, max score 9
# Completed 449 games, 866 rewards, 208854 frames, score 1, max score 9
# Completed 450 games, 868 rewards, 209237 frames, score 1, max score 9
# Completed 451 games, 872 rewards, 210317 frames, score 3, max score 9
# Completed 452 games, 876 rewards, 210992 frames, score 3, max score 9
# Completed 453 games, 877 rewards, 211200 frames, score 0, max score 9
# Completed 454 games, 880 rewards, 211843 frames, score 2, max score 9
# Completed 455 games, 882 rewards, 212505 frames, score 1, max score 9
# Completed 456 games, 883 rewards, 212686 frames, score 0, max score 9
# Completed 457 games, 884 rewards, 212867 frames, score 0, max score 9
# Completed 458 games, 885 rewards, 213121 frames, score 0, max score 9
# Completed 459 games, 890 rewards, 214192 frames, score 4, max score 9
# Completed 460 games, 894 rewards, 214935 frames, score 3, max score 9
# Completed 461 games, 897 rewards, 215911 frames, score 2, max score 9
# Completed 462 games, 898 rewards, 216092 frames, score 0, max score 9
# Completed 463 games, 900 rewards, 216589 frames, score 1, max score 9
# Completed 464 games, 905 rewards, 217372 frames, score 4, max score 9
# Completed 465 games, 906 rewards, 217580 frames, score 0, max score 9
# Completed 466 games, 907 rewards, 217761 frames, score 0, max score 9
# Completed 467 games, 910 rewards, 218453 frames, score 2, max score 9
# Completed 468 games, 913 rewards, 219209 frames, score 2, max score 9
# Completed 469 games, 914 rewards, 219417 frames, score 0, max score 9
# Completed 470 games, 916 rewards, 219914 frames, score 1, max score 9
# Completed 471 games, 918 rewards, 220328 frames, score 1, max score 9
# Completed 472 games, 923 rewards, 221247 frames, score 4, max score 9
# Completed 473 games, 924 rewards, 221428 frames, score 0, max score 9
# Completed 474 games, 925 rewards, 221609 frames, score 0, max score 9
# Completed 475 games, 926 rewards, 221817 frames, score 0, max score 9
# Completed 476 games, 931 rewards, 225175 frames, score 4, max score 9
# Completed 477 games, 937 rewards, 226529 frames, score 5, max score 9
# Completed 478 games, 938 rewards, 226737 frames, score 0, max score 9
# Completed 479 games, 939 rewards, 226945 frames, score 0, max score 9
# Completed 480 games, 940 rewards, 227153 frames, score 0, max score 9
# Completed 481 games, 942 rewards, 227536 frames, score 1, max score 9
# Completed 482 games, 945 rewards, 228201 frames, score 2, max score 9
# Completed 483 games, 947 rewards, 228542 frames, score 1, max score 9
# Completed 484 games, 956 rewards, 232253 frames, score 8, max score 9
# Completed 485 games, 959 rewards, 232788 frames, score 2, max score 9
# Completed 486 games, 963 rewards, 233986 frames, score 3, max score 9
# Completed 487 games, 966 rewards, 235096 frames, score 2, max score 9
# Completed 488 games, 978 rewards, 237174 frames, score 11, max score 11
# Completed 489 games, 984 rewards, 240948 frames, score 5, max score 11
# Completed 490 games, 988 rewards, 242075 frames, score 3, max score 11
# Completed 491 games, 995 rewards, 244880 frames, score 6, max score 11
# Completed 492 games, 998 rewards, 245470 frames, score 2, max score 11
# Completed 493 games, 1000 rewards, 245898 frames, score 1, max score 11
# Completed 494 games, 1001 rewards, 246079 frames, score 0, max score 11
# Completed 495 games, 1006 rewards, 247892 frames, score 4, max score 11
# Completed 496 games, 1009 rewards, 248754 frames, score 2, max score 11
# Completed 497 games, 1011 rewards, 249095 frames, score 1, max score 11
# Completed 498 games, 1015 rewards, 249918 frames, score 3, max score 11
# Completed 499 games, 1016 rewards, 250099 frames, score 0, max score 11
# Completed 500 games, 1019 rewards, 250912 frames, score 2, max score 11
# Completed 501 games, 1022 rewards, 251698 frames, score 2, max score 11
# Completed 502 games, 1024 rewards, 252142 frames, score 1, max score 11
# Completed 503 games, 1034 rewards, 257847 frames, score 9, max score 11
# Completed 504 games, 1037 rewards, 258467 frames, score 2, max score 11
# Completed 505 games, 1038 rewards, 258675 frames, score 0, max score 11
# Completed 506 games, 1039 rewards, 258883 frames, score 0, max score 11
# Completed 507 games, 1041 rewards, 259343 frames, score 1, max score 11
# Completed 508 games, 1045 rewards, 260124 frames, score 3, max score 11
# Completed 509 games, 1047 rewards, 260476 frames, score 1, max score 11
# Completed 510 games, 1057 rewards, 262952 frames, score 9, max score 11
# Completed 511 games, 1058 rewards, 263160 frames, score 0, max score 11
# Completed 512 games, 1059 rewards, 263414 frames, score 0, max score 11
# Completed 513 games, 1060 rewards, 263668 frames, score 0, max score 11
# Completed 514 games, 1063 rewards, 264360 frames, score 2, max score 11
# Completed 515 games, 1064 rewards, 264541 frames, score 0, max score 11
# Completed 516 games, 1065 rewards, 264795 frames, score 0, max score 11
# Completed 517 games, 1068 rewards, 265457 frames, score 2, max score 11
# Completed 518 games, 1084 rewards, 268813 frames, score 15, max score 15
# Completed 519 games, 1086 rewards, 269187 frames, score 1, max score 15
# Completed 520 games, 1096 rewards, 272081 frames, score 9, max score 15
# Completed 521 games, 1097 rewards, 272335 frames, score 0, max score 15
# Completed 522 games, 1100 rewards, 272900 frames, score 2, max score 15
# Completed 523 games, 1101 rewards, 273108 frames, score 0, max score 15
# Completed 524 games, 1110 rewards, 277709 frames, score 8, max score 15
# Completed 525 games, 1112 rewards, 278137 frames, score 1, max score 15
# Completed 526 games, 1115 rewards, 278788 frames, score 2, max score 15
# Completed 527 games, 1117 rewards, 279175 frames, score 1, max score 15
# Completed 528 games, 1122 rewards, 280053 frames, score 4, max score 15
# Completed 529 games, 1125 rewards, 280697 frames, score 2, max score 15
# Completed 530 games, 1127 rewards, 281248 frames, score 1, max score 15
# Completed 531 games, 1134 rewards, 286519 frames, score 6, max score 15
# Completed 532 games, 1135 rewards, 286727 frames, score 0, max score 15
# Completed 533 games, 1140 rewards, 287692 frames, score 4, max score 15
# Completed 534 games, 1142 rewards, 288075 frames, score 1, max score 15
# Completed 535 games, 1146 rewards, 288936 frames, score 3, max score 15
# Completed 536 games, 1147 rewards, 289144 frames, score 0, max score 15
# Completed 537 games, 1150 rewards, 289752 frames, score 2, max score 15
# Completed 538 games, 1151 rewards, 290006 frames, score 0, max score 15
# Completed 539 games, 1154 rewards, 290571 frames, score 2, max score 15
# Completed 540 games, 1156 rewards, 291233 frames, score 1, max score 15
# Completed 541 games, 1161 rewards, 293253 frames, score 4, max score 15
# Completed 542 games, 1165 rewards, 294540 frames, score 3, max score 15
# Completed 543 games, 1169 rewards, 295360 frames, score 3, max score 15
# Completed 544 games, 1171 rewards, 295765 frames, score 1, max score 15
# Completed 545 games, 1173 rewards, 296684 frames, score 1, max score 15
# Completed 546 games, 1174 rewards, 296938 frames, score 0, max score 15
# Completed 547 games, 1178 rewards, 298900 frames, score 3, max score 15
# Completed 548 games, 1180 rewards, 299562 frames, score 1, max score 15
# Completed 549 games, 1182 rewards, 300224 frames, score 1, max score 15
# Completed 550 games, 1184 rewards, 300661 frames, score 1, max score 15
# Completed 551 games, 1188 rewards, 301351 frames, score 3, max score 15
# Completed 552 games, 1189 rewards, 301559 frames, score 0, max score 15
# Completed 553 games, 1190 rewards, 301813 frames, score 0, max score 15
# Completed 554 games, 1191 rewards, 302067 frames, score 0, max score 15
# Completed 555 games, 1193 rewards, 302450 frames, score 1, max score 15
# Completed 556 games, 1195 rewards, 303128 frames, score 1, max score 15
# Completed 557 games, 1196 rewards, 303336 frames, score 0, max score 15
# Completed 558 games, 1197 rewards, 303544 frames, score 0, max score 15
# Completed 559 games, 1202 rewards, 304653 frames, score 4, max score 15
# Completed 560 games, 1203 rewards, 304907 frames, score 0, max score 15
# Completed 561 games, 1210 rewards, 306526 frames, score 6, max score 15
# Completed 562 games, 1212 rewards, 306940 frames, score 1, max score 15
# Completed 563 games, 1215 rewards, 308023 frames, score 2, max score 15
# Completed 564 games, 1218 rewards, 308613 frames, score 2, max score 15
# Completed 565 games, 1219 rewards, 308867 frames, score 0, max score 15
# Completed 566 games, 1220 rewards, 309075 frames, score 0, max score 15
# Completed 567 games, 1221 rewards, 309329 frames, score 0, max score 15
# Completed 568 games, 1226 rewards, 313667 frames, score 4, max score 15
# Completed 569 games, 1229 rewards, 314398 frames, score 2, max score 15
# Completed 570 games, 1232 rewards, 315066 frames, score 2, max score 15
# Completed 571 games, 1233 rewards, 315320 frames, score 0, max score 15
# Completed 572 games, 1236 rewards, 315890 frames, score 2, max score 15
# Completed 573 games, 1239 rewards, 316928 frames, score 2, max score 15
# Completed 574 games, 1241 rewards, 317365 frames, score 1, max score 15
# Completed 575 games, 1243 rewards, 317732 frames, score 1, max score 15
# Completed 576 games, 1251 rewards, 319872 frames, score 7, max score 15
# Completed 577 games, 1252 rewards, 320080 frames, score 0, max score 15
# Completed 578 games, 1258 rewards, 321355 frames, score 5, max score 15
# Completed 579 games, 1262 rewards, 322046 frames, score 3, max score 15
# Completed 580 games, 1266 rewards, 322866 frames, score 3, max score 15
# Completed 581 games, 1269 rewards, 323346 frames, score 2, max score 15
# Completed 582 games, 1270 rewards, 323554 frames, score 0, max score 15
# Completed 583 games, 1272 rewards, 324134 frames, score 1, max score 15
# Completed 584 games, 1273 rewards, 324388 frames, score 0, max score 15
# Completed 585 games, 1276 rewards, 324976 frames, score 2, max score 15
# Completed 586 games, 1281 rewards, 326304 frames, score 4, max score 15
# Completed 587 games, 1288 rewards, 329863 frames, score 6, max score 15
# Completed 588 games, 1289 rewards, 330117 frames, score 0, max score 15
# Completed 589 games, 1290 rewards, 330325 frames, score 0, max score 15
# Completed 590 games, 1295 rewards, 331138 frames, score 4, max score 15
# Completed 591 games, 1300 rewards, 332195 frames, score 4, max score 15
# Completed 592 games, 1310 rewards, 334228 frames, score 9, max score 15
# Completed 593 games, 1313 rewards, 334744 frames, score 2, max score 15
# Completed 594 games, 1315 rewards, 335150 frames, score 1, max score 15
# Completed 595 games, 1321 rewards, 336405 frames, score 5, max score 15
# Completed 596 games, 1322 rewards, 336613 frames, score 0, max score 15
# Completed 597 games, 1325 rewards, 338147 frames, score 2, max score 15
# Completed 598 games, 1329 rewards, 338947 frames, score 3, max score 15
# Completed 599 games, 1330 rewards, 339128 frames, score 0, max score 15
# Completed 600 games, 1332 rewards, 339640 frames, score 1, max score 15
# Completed 601 games, 1333 rewards, 339894 frames, score 0, max score 15
# Completed 602 games, 1334 rewards, 340102 frames, score 0, max score 15
# Completed 603 games, 1335 rewards, 340356 frames, score 0, max score 15
# Completed 604 games, 1341 rewards, 341931 frames, score 5, max score 15
# Completed 605 games, 1343 rewards, 342359 frames, score 1, max score 15
# Completed 606 games, 1345 rewards, 342711 frames, score 1, max score 15
# Completed 607 games, 1346 rewards, 342892 frames, score 0, max score 15
# Completed 608 games, 1349 rewards, 343992 frames, score 2, max score 15
# Completed 609 games, 1356 rewards, 345180 frames, score 6, max score 15
# Completed 610 games, 1359 rewards, 346119 frames, score 2, max score 15
# Completed 611 games, 1360 rewards, 346373 frames, score 0, max score 15
# Completed 612 games, 1361 rewards, 346554 frames, score 0, max score 15
# Completed 613 games, 1363 rewards, 346922 frames, score 1, max score 15
# Completed 614 games, 1366 rewards, 347430 frames, score 2, max score 15
# Completed 615 games, 1367 rewards, 347611 frames, score 0, max score 15
# Completed 616 games, 1369 rewards, 348108 frames, score 1, max score 15
# Completed 617 games, 1371 rewards, 348476 frames, score 1, max score 15
# Completed 618 games, 1373 rewards, 348844 frames, score 1, max score 15
# Completed 619 games, 1374 rewards, 349098 frames, score 0, max score 15
# Completed 620 games, 1377 rewards, 349847 frames, score 2, max score 15
# Completed 621 games, 1380 rewards, 350823 frames, score 2, max score 15
# Completed 622 games, 1387 rewards, 353191 frames, score 6, max score 15
# Completed 623 games, 1389 rewards, 353679 frames, score 1, max score 15
# Completed 624 games, 1391 rewards, 354213 frames, score 1, max score 15
# Completed 625 games, 1394 rewards, 354739 frames, score 2, max score 15
# Completed 626 games, 1396 rewards, 355329 frames, score 1, max score 15
# Completed 627 games, 1398 rewards, 355817 frames, score 1, max score 15
# Completed 628 games, 1401 rewards, 356732 frames, score 2, max score 15
# Completed 629 games, 1402 rewards, 356986 frames, score 0, max score 15
# Completed 630 games, 1403 rewards, 357194 frames, score 0, max score 15
# Completed 631 games, 1408 rewards, 359421 frames, score 4, max score 15
# Completed 632 games, 1412 rewards, 360883 frames, score 3, max score 15
# Completed 633 games, 1413 rewards, 361137 frames, score 0, max score 15
# Completed 634 games, 1414 rewards, 361391 frames, score 0, max score 15
# Completed 635 games, 1415 rewards, 361572 frames, score 0, max score 15
# Completed 636 games, 1416 rewards, 361753 frames, score 0, max score 15
# Completed 637 games, 1422 rewards, 363063 frames, score 5, max score 15
# Completed 638 games, 1423 rewards, 363317 frames, score 0, max score 15
# Completed 639 games, 1425 rewards, 364283 frames, score 1, max score 15
# Completed 640 games, 1426 rewards, 364464 frames, score 0, max score 15
# Completed 641 games, 1427 rewards, 364718 frames, score 0, max score 15
# Completed 642 games, 1428 rewards, 364972 frames, score 0, max score 15
# Completed 643 games, 1432 rewards, 366159 frames, score 3, max score 15
# Completed 644 games, 1433 rewards, 366367 frames, score 0, max score 15
# Completed 645 games, 1435 rewards, 366947 frames, score 1, max score 15
# Completed 646 games, 1439 rewards, 367758 frames, score 3, max score 15
# Completed 647 games, 1440 rewards, 368012 frames, score 0, max score 15
# Completed 648 games, 1444 rewards, 368995 frames, score 3, max score 15
# Completed 649 games, 1446 rewards, 369455 frames, score 1, max score 15
# Completed 650 games, 1451 rewards, 370755 frames, score 4, max score 15
# Completed 651 games, 1453 rewards, 371357 frames, score 1, max score 15
# Completed 652 games, 1457 rewards, 372140 frames, score 3, max score 15
# Completed 653 games, 1462 rewards, 374005 frames, score 4, max score 15
# Completed 654 games, 1465 rewards, 374539 frames, score 2, max score 15
# Completed 655 games, 1467 rewards, 375273 frames, score 1, max score 15
# Completed 656 games, 1468 rewards, 375527 frames, score 0, max score 15
# Completed 657 games, 1470 rewards, 375987 frames, score 1, max score 15
# Completed 658 games, 1476 rewards, 379686 frames, score 5, max score 15
# Completed 659 games, 1482 rewards, 380918 frames, score 5, max score 15
# Completed 660 games, 1484 rewards, 381270 frames, score 1, max score 15
# Completed 661 games, 1487 rewards, 381802 frames, score 2, max score 15
# Completed 662 games, 1488 rewards, 382010 frames, score 0, max score 15
# Completed 663 games, 1492 rewards, 382862 frames, score 3, max score 15
# Completed 664 games, 1494 rewards, 383267 frames, score 1, max score 15
# Completed 665 games, 1500 rewards, 384874 frames, score 5, max score 15
# Completed 666 games, 1502 rewards, 385362 frames, score 1, max score 15
# Completed 667 games, 1506 rewards, 386129 frames, score 3, max score 15
# Completed 668 games, 1509 rewards, 386899 frames, score 2, max score 15
# Completed 669 games, 1515 rewards, 387874 frames, score 5, max score 15
# Completed 670 games, 1520 rewards, 389486 frames, score 4, max score 15
# Completed 671 games, 1522 rewards, 389838 frames, score 1, max score 15
# Completed 672 games, 1525 rewards, 390595 frames, score 2, max score 15
# Completed 673 games, 1530 rewards, 393512 frames, score 4, max score 15
# Completed 674 games, 1533 rewards, 394011 frames, score 2, max score 15
# Completed 675 games, 1536 rewards, 394601 frames, score 2, max score 15
# Completed 676 games, 1539 rewards, 395291 frames, score 2, max score 15
# Completed 677 games, 1545 rewards, 396762 frames, score 5, max score 15
# Completed 678 games, 1548 rewards, 397553 frames, score 2, max score 15
# Completed 679 games, 1552 rewards, 398697 frames, score 3, max score 15
# Completed 680 games, 1554 rewards, 399359 frames, score 1, max score 15
# Completed 681 games, 1572 rewards, 404050 frames, score 17, max score 17
# Completed 682 games, 1574 rewards, 404456 frames, score 1, max score 17
# Completed 683 games, 1582 rewards, 405585 frames, score 7, max score 17
# Completed 684 games, 1584 rewards, 405991 frames, score 1, max score 17
# Completed 685 games, 1586 rewards, 406488 frames, score 1, max score 17
# ...
# Completed 2033 games, 27548 rewards, 5994855 frames, score 3, max score 250
# Completed 2034 games, 27561 rewards, 5997549 frames, score 12, max score 250
# Completed 2035 games, 27626 rewards, 6014958 frames, score 64, max score 250
# Completed 2036 games, 27629 rewards, 6015821 frames, score 2, max score 250
# Completed 2037 games, 27632 rewards, 6016564 frames, score 2, max score 250
# Completed 2038 games, 27678 rewards, 6027718 frames, score 45, max score 250
# Completed 2039 games, 27682 rewards, 6028574 frames, score 3, max score 250
# Completed 2040 games, 27694 rewards, 6030875 frames, score 11, max score 250
# Completed 2041 games, 27698 rewards, 6031818 frames, score 3, max score 250
# Completed 2042 games, 27721 rewards, 6035452 frames, score 22, max score 250
# Completed 2043 games, 27766 rewards, 6042864 frames, score 44, max score 250
# Completed 2044 games, 27793 rewards, 6047556 frames, score 26, max score 250
# Completed 2045 games, 27800 rewards, 6049198 frames, score 6, max score 250
# Completed 2046 games, 27820 rewards, 6060093 frames, score 19, max score 250
# Completed 2047 games, 27824 rewards, 6062062 frames, score 3, max score 250
# Completed 2048 games, 27834 rewards, 6064539 frames, score 9, max score 250
# Completed 2049 games, 27836 rewards, 6064931 frames, score 1, max score 250
# Completed 2050 games, 27853 rewards, 6067776 frames, score 16, max score 250
# Completed 2051 games, 27857 rewards, 6068396 frames, score 3, max score 250
# Completed 2052 games, 27875 rewards, 6071717 frames, score 17, max score 250
# Completed 2053 games, 27899 rewards, 6077555 frames, score 23, max score 250
# Completed 2054 games, 27954 rewards, 6087872 frames, score 54, max score 250
# Completed 2055 games, 27997 rewards, 6098447 frames, score 42, max score 250
# Completed 2056 games, 28002 rewards, 6099264 frames, score 4, max score 250
# Completed 2057 games, 28007 rewards, 6101408 frames, score 4, max score 250
# Completed 2058 games, 28025 rewards, 6104189 frames, score 17, max score 250
# Completed 2059 games, 28119 rewards, 6118296 frames, score 93, max score 250
# Completed 2060 games, 28125 rewards, 6119925 frames, score 5, max score 250
# Completed 2061 games, 28134 rewards, 6121682 frames, score 8, max score 250
# Completed 2062 games, 28140 rewards, 6123718 frames, score 5, max score 250
# Completed 2063 games, 28156 rewards, 6127759 frames, score 15, max score 250
# Completed 2064 games, 28223 rewards, 6145137 frames, score 66, max score 250
# Completed 2065 games, 28230 rewards, 6147314 frames, score 6, max score 250
# Completed 2066 games, 28242 rewards, 6149361 frames, score 11, max score 250
# Completed 2067 games, 28281 rewards, 6160543 frames, score 38, max score 250
# Completed 2068 games, 28288 rewards, 6162238 frames, score 6, max score 250
# Completed 2069 games, 28300 rewards, 6167509 frames, score 11, max score 250
# Completed 2070 games, 28318 rewards, 6170446 frames, score 17, max score 250
# Completed 2071 games, 28326 rewards, 6172136 frames, score 7, max score 250
# Completed 2072 games, 28357 rewards, 6179717 frames, score 30, max score 250
# Completed 2073 games, 28358 rewards, 6179971 frames, score 0, max score 250
# Completed 2074 games, 28395 rewards, 6197955 frames, score 36, max score 250
# Completed 2075 games, 28454 rewards, 6209866 frames, score 58, max score 250
# Completed 2076 games, 28476 rewards, 6214816 frames, score 21, max score 250
# Completed 2077 games, 28492 rewards, 6218388 frames, score 15, max score 250
# Completed 2078 games, 28509 rewards, 6221227 frames, score 16, max score 250
# Completed 2079 games, 28513 rewards, 6222391 frames, score 3, max score 250
# Completed 2080 games, 28551 rewards, 6230985 frames, score 37, max score 250
# Completed 2081 games, 28561 rewards, 6233729 frames, score 9, max score 250
# Completed 2082 games, 28571 rewards, 6235428 frames, score 9, max score 250
# Completed 2083 games, 28596 rewards, 6242375 frames, score 24, max score 250
# Completed 2084 games, 28598 rewards, 6242803 frames, score 1, max score 250
# Completed 2085 games, 28604 rewards, 6243879 frames, score 5, max score 250
# Completed 2086 games, 28617 rewards, 6246109 frames, score 12, max score 250
# Completed 2087 games, 28637 rewards, 6249517 frames, score 19, max score 250
# Completed 2088 games, 28657 rewards, 6252476 frames, score 19, max score 250
# Completed 2089 games, 28762 rewards, 6268155 frames, score 104, max score 250
# Completed 2090 games, 28777 rewards, 6271294 frames, score 14, max score 250
# Completed 2091 games, 28789 rewards, 6273214 frames, score 11, max score 250
# Completed 2092 games, 28856 rewards, 6283211 frames, score 66, max score 250
# Completed 2093 games, 28878 rewards, 6286869 frames, score 21, max score 250
# Completed 2094 games, 28884 rewards, 6288289 frames, score 5, max score 250
# Completed 2095 games, 28891 rewards, 6289412 frames, score 6, max score 250
# Completed 2096 games, 28912 rewards, 6293293 frames, score 20, max score 250
# Completed 2097 games, 28940 rewards, 6297952 frames, score 27, max score 250
# Completed 2098 games, 28951 rewards, 6300003 frames, score 10, max score 250
# Completed 2099 games, 28953 rewards, 6300547 frames, score 1, max score 250
# Completed 2100 games, 28977 rewards, 6304932 frames, score 23, max score 250
# Completed 2101 games, 29015 rewards, 6312172 frames, score 37, max score 250
# Completed 2102 games, 29025 rewards, 6313698 frames, score 9, max score 250
# Completed 2103 games, 29052 rewards, 6318816 frames, score 26, max score 250
# Completed 2104 games, 29070 rewards, 6321660 frames, score 17, max score 250
# Completed 2105 games, 29087 rewards, 6324384 frames, score 16, max score 250
# Completed 2106 games, 29127 rewards, 6330385 frames, score 39, max score 250
# Completed 2107 games, 29147 rewards, 6334357 frames, score 19, max score 250
# Completed 2108 games, 29150 rewards, 6334927 frames, score 2, max score 250
# Completed 2109 games, 29165 rewards, 6338368 frames, score 14, max score 250
# Completed 2110 games, 29171 rewards, 6339503 frames, score 5, max score 250
# Completed 2111 games, 29192 rewards, 6343588 frames, score 20, max score 250
# Completed 2112 games, 29203 rewards, 6345447 frames, score 10, max score 250
# Completed 2113 games, 29208 rewards, 6347419 frames, score 4, max score 250
# Completed 2114 games, 29233 rewards, 6357230 frames, score 24, max score 250
# Completed 2115 games, 29245 rewards, 6364674 frames, score 11, max score 250
# Completed 2116 games, 29257 rewards, 6367080 frames, score 11, max score 250
# Completed 2117 games, 29291 rewards, 6372622 frames, score 33, max score 250
# Completed 2118 games, 29298 rewards, 6374572 frames, score 6, max score 250
# Completed 2119 games, 29315 rewards, 6378435 frames, score 16, max score 250
# Completed 2120 games, 29332 rewards, 6381310 frames, score 16, max score 250
# Completed 2121 games, 29334 rewards, 6381972 frames, score 1, max score 250
# Completed 2122 games, 29336 rewards, 6382435 frames, score 1, max score 250
# Completed 2123 games, 29344 rewards, 6384106 frames, score 7, max score 250
# Completed 2124 games, 29387 rewards, 6393835 frames, score 42, max score 250
# Completed 2125 games, 29397 rewards, 6395477 frames, score 9, max score 250
# Completed 2126 games, 29414 rewards, 6398930 frames, score 16, max score 250
# Completed 2127 games, 29427 rewards, 6404222 frames, score 12, max score 250
# Completed 2128 games, 29471 rewards, 6410944 frames, score 43, max score 250
# Completed 2129 games, 29487 rewards, 6413288 frames, score 15, max score 250
# Completed 2130 games, 29506 rewards, 6416551 frames, score 18, max score 250
# Completed 2131 games, 29529 rewards, 6419860 frames, score 22, max score 250
# Completed 2132 games, 29590 rewards, 6430674 frames, score 60, max score 250
# Completed 2133 games, 29617 rewards, 6435109 frames, score 26, max score 250
# Completed 2134 games, 29694 rewards, 6447427 frames, score 76, max score 250
# Completed 2135 games, 29700 rewards, 6448847 frames, score 5, max score 250
# Completed 2136 games, 29711 rewards, 6452302 frames, score 10, max score 250
# Completed 2137 games, 29752 rewards, 6459104 frames, score 40, max score 250
# Completed 2138 games, 29764 rewards, 6460883 frames, score 11, max score 250
# Completed 2139 games, 29768 rewards, 6461627 frames, score 3, max score 250
# Completed 2140 games, 29805 rewards, 6469118 frames, score 36, max score 250
# Completed 2141 games, 29821 rewards, 6471658 frames, score 15, max score 250
# Completed 2142 games, 29831 rewards, 6473632 frames, score 9, max score 250
# Completed 2143 games, 29844 rewards, 6476929 frames, score 12, max score 250
# Completed 2144 games, 29869 rewards, 6487401 frames, score 24, max score 250
# Completed 2145 games, 29906 rewards, 6495835 frames, score 36, max score 250
# Completed 2146 games, 29933 rewards, 6501120 frames, score 26, max score 250
# Completed 2147 games, 30030 rewards, 6518740 frames, score 96, max score 250
# Completed 2148 games, 30096 rewards, 6530070 frames, score 65, max score 250
# Completed 2149 games, 30115 rewards, 6533989 frames, score 18, max score 250
# Completed 2150 games, 30165 rewards, 6541879 frames, score 49, max score 250
# Completed 2151 games, 30223 rewards, 6551078 frames, score 57, max score 250
# Completed 2152 games, 30272 rewards, 6558680 frames, score 48, max score 250
# Completed 2153 games, 30321 rewards, 6566766 frames, score 48, max score 250
# Completed 2154 games, 30351 rewards, 6572543 frames, score 29, max score 250
# Completed 2155 games, 30402 rewards, 6581746 frames, score 50, max score 250
# Completed 2156 games, 30418 rewards, 6587991 frames, score 15, max score 250
# Completed 2157 games, 30568 rewards, 6627130 frames, score 149, max score 250
# Completed 2158 games, 30656 rewards, 6642877 frames, score 87, max score 250
# Completed 2159 games, 30699 rewards, 6649790 frames, score 42, max score 250
# Completed 2160 games, 30701 rewards, 6650380 frames, score 1, max score 250
# Completed 2161 games, 30748 rewards, 6662455 frames, score 46, max score 250
# Completed 2162 games, 30753 rewards, 6663395 frames, score 4, max score 250
# Completed 2163 games, 30760 rewards, 6665219 frames, score 6, max score 250
# Completed 2164 games, 30784 rewards, 6670047 frames, score 23, max score 250
# Completed 2165 games, 30798 rewards, 6676555 frames, score 13, max score 250
# Completed 2166 games, 30823 rewards, 6682785 frames, score 24, max score 250
# Completed 2167 games, 30898 rewards, 6712775 frames, score 74, max score 250
# Completed 2168 games, 30960 rewards, 6730697 frames, score 61, max score 250
# Completed 2169 games, 30971 rewards, 6734691 frames, score 10, max score 250
# Completed 2170 games, 30997 rewards, 6741548 frames, score 25, max score 250
# Completed 2171 games, 31081 rewards, 6760642 frames, score 83, max score 250
# Completed 2172 games, 31092 rewards, 6762382 frames, score 10, max score 250
# Completed 2173 games, 31102 rewards, 6764120 frames, score 9, max score 250
# Completed 2174 games, 31167 rewards, 6773822 frames, score 64, max score 250
# Completed 2175 games, 31255 rewards, 6793337 frames, score 87, max score 250
# Completed 2176 games, 31271 rewards, 6796530 frames, score 15, max score 250
# Completed 2177 games, 31282 rewards, 6798286 frames, score 10, max score 250
# Completed 2178 games, 31299 rewards, 6801544 frames, score 16, max score 250
# Completed 2179 games, 31373 rewards, 6815093 frames, score 73, max score 250
# Completed 2180 games, 31424 rewards, 6827056 frames, score 50, max score 250
# Completed 2181 games, 31475 rewards, 6835588 frames, score 50, max score 250
# Completed 2182 games, 31489 rewards, 6838288 frames, score 13, max score 250
# Completed 2183 games, 31516 rewards, 6842609 frames, score 26, max score 250
# Completed 2184 games, 31681 rewards, 6873644 frames, score 164, max score 250
# Completed 2185 games, 31706 rewards, 6877868 frames, score 24, max score 250
# Completed 2186 games, 31915 rewards, 6913431 frames, score 208, max score 250
# Completed 2187 games, 32048 rewards, 6942751 frames, score 132, max score 250
# Completed 2188 games, 32203 rewards, 6973023 frames, score 154, max score 250
# Completed 2189 games, 32464 rewards, 7018340 frames, score 260, max score 260
# Completed 2190 games, 32589 rewards, 7041773 frames, score 124, max score 260
# Completed 2191 games, 32634 rewards, 7049577 frames, score 44, max score 260
# Completed 2192 games, 32649 rewards, 7055024 frames, score 14, max score 260
# Completed 2193 games, 32672 rewards, 7059694 frames, score 22, max score 260
# Completed 2194 games, 32675 rewards, 7060201 frames, score 2, max score 260
# Completed 2195 games, 32774 rewards, 7076484 frames, score 98, max score 260
# Completed 2196 games, 32794 rewards, 7080084 frames, score 19, max score 260
# Completed 2197 games, 32808 rewards, 7083444 frames, score 13, max score 260
# Completed 2198 games, 32930 rewards, 7110847 frames, score 121, max score 260
# Completed 2199 games, 32953 rewards, 7115085 frames, score 22, max score 260
# Completed 2200 games, 33020 rewards, 7130919 frames, score 66, max score 260
# Completed 2201 games, 33039 rewards, 7133823 frames, score 18, max score 260
# Completed 2202 games, 33122 rewards, 7151741 frames, score 82, max score 260
# Completed 2203 games, 33148 rewards, 7156315 frames, score 25, max score 260
# Completed 2204 games, 33195 rewards, 7169083 frames, score 46, max score 260
# Completed 2205 games, 33201 rewards, 7170263 frames, score 5, max score 260
# Completed 2206 games, 33286 rewards, 7183266 frames, score 84, max score 260
# Completed 2207 games, 33310 rewards, 7187384 frames, score 23, max score 260
# Completed 2208 games, 33314 rewards, 7188400 frames, score 3, max score 260
# Completed 2209 games, 33357 rewards, 7195741 frames, score 42, max score 260
# Completed 2210 games, 33391 rewards, 7203194 frames, score 33, max score 260
# Completed 2211 games, 33403 rewards, 7206263 frames, score 11, max score 260
# Completed 2212 games, 33574 rewards, 7242151 frames, score 170, max score 260
# Completed 2213 games, 33585 rewards, 7243988 frames, score 10, max score 260
# Completed 2214 games, 33629 rewards, 7256115 frames, score 43, max score 260
# Completed 2215 games, 33698 rewards, 7276589 frames, score 68, max score 260
# Completed 2216 games, 33716 rewards, 7279602 frames, score 17, max score 260
# Completed 2217 games, 33734 rewards, 7283188 frames, score 17, max score 260
# Completed 2218 games, 33806 rewards, 7296728 frames, score 71, max score 260
# Completed 2219 games, 33883 rewards, 7309390 frames, score 76, max score 260
# Completed 2220 games, 33933 rewards, 7319654 frames, score 49, max score 260
# Completed 2221 games, 33978 rewards, 7326374 frames, score 44, max score 260
# Completed 2222 games, 33984 rewards, 7327992 frames, score 5, max score 260
# Completed 2223 games, 34089 rewards, 7347003 frames, score 104, max score 260
# Completed 2224 games, 34111 rewards, 7351618 frames, score 21, max score 260
# Completed 2225 games, 34288 rewards, 7378493 frames, score 176, max score 260
# Completed 2226 games, 34311 rewards, 7387407 frames, score 22, max score 260
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 scores, q_achieved, q_states = pong_game.run(m_games=5000, states=[])
#       3 print('The number of games played was',len(scores))
#       4 print('The number of video frames was',len(q_states))
#
# File ~/Desktop/ECE 448/AI_Repo/mp11/pong.py:180, in PongGame.run(self, m_rewards, m_games, m_frames, states)
#     178     action = self.learner.act(state)
#     179 else:
# --> 180     action = self.learner.act(self.quantize_state(state))
#     181 if action != None:
#     182     paddle_v = action * self.paddle_speed
#
# File ~/Desktop/ECE 448/AI_Repo/mp11/submitted.py:259, in q_learner.act(self, state)
#     256   action_list.append(-1)
#     258 if(len(action_list) == 0):
# --> 259   test = np.random.choice(np.arange(0, 2), p=[self.epsilon, 1 - self.epsilon])
#     260   if(test == 1):
#     261     q_current = list(self.report_q(state))
#
# KeyboardInterrupt:

# %% [markdown]
# Now let's plot the score, to see if it improved over time.  We will also plot the local average, averaged over 10 consecutive games, to see if that has improved.  Notice that we can use `np.convolve` to compute the local average.
#
# These numbers are really noisy, with a really large maximum.  We will plot `np.log10(1+x)`, rather than x, so that we can better see the average numbers, and ignore the very large noisy spikes.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(14,9),layout='tight')
ax = [ fig.add_subplot(3,1,x) for x in range(1,4) ]
ax[0].plot(np.arange(0,len(scores)),np.log10(1+np.array(scores)))
ax[0].plot([0,5000],np.log10([7,7]),'k--')
ax[0].set_title('Game scores')
ax[1].plot(np.arange(4991),np.log10(1+np.convolve(np.ones(10)/10,scores,mode='valid')))
ax[1].plot([0,4991],np.log10([7,7]),'k--')
ax[1].set_title('Game scores, average 10 consecutive games')
ax[2].plot(np.arange(0,len(q_achieved)),q_achieved)
ax[2].set_title('Q values of state achieved at each time')
ax[2].set_ylabel('Game number')
# Out:
# Text(0, 0.5, 'Game number')

# %% [markdown]
# Hooray, it has learned!  If you are getting a ten-game average score of better than 6, then you are ready to submit your model for grading.   In order to do that, you need to save the model:

# %%
q_learner.save('trained_model.npz')

# %% [markdown]
# <a id='section9'></a>

# %% [markdown]
# ## Extra Credit

# %% [markdown]
# For extra credit, download the file <a href="mp11_extra.zip">mp11_extra.zip</a>.  The only important file in this package is:
# * `tests/test_extra.py`: this contains extra tests that will evaluate your pre-trained `deep_q` learner, which should be in a file called `trained_model.pkl`.  For full credit, your model should achieve an average score of greater than 20, averaged over 10 consecutive games.
#
# With a quantized lookup table, it's probably not possible to achieve an average score of 20.  With a deep-Q learner, however, it is eminently possible.  In order to do the extra credit, therefore, you should just fill in the part of `submitted.py` that implements the `deep_q` learner, using pytorch to define a model structure, train it, save it, load it, and act on it.  This learner only needs to have five methods: `__init__`, `act`, `learn`, `save`, and `load`:

# %%
importlib.reload(submitted)
help(submitted.deep_q.__init__)
# Out:
# Help on function __init__ in module submitted:
#
# __init__(self, alpha, epsilon, gamma, nfirst)
#     Create a new deep_q learner.
#     Your q_learner object should store the provided values of alpha,
#     epsilon, gamma, and nfirst.
#     It should also create a deep learning model that will accept
#     (state,action) as input, and estimate Q as the output.
#
#     @params:
#     alpha (scalar) - learning rate of the Q-learner
#     epsilon (scalar) - probability of taking a random action
#     gamma (scalar) - discount factor
#     nfirst (scalar) - exploring each state/action pair nfirst times before exploiting
#
#     @return:
#     None

# %%
help(submitted.deep_q.act)
# Out:
# Help on function act in module submitted:
#
# act(self, state)
#     Decide what action to take in the current state.
#     You are free to determine your own exploration/exploitation policy --
#     you don't need to use the epsilon and nfirst provided to you.
#
#     @params:
#     state: a list of 5 floats: ball_x, ball_y, ball_vx, ball_vy, paddle_y.
#
#     @return:
#     -1 if the paddle should move upward
#     0 if the paddle should be stationary
#     1 if the paddle should move downward

# %%
help(submitted.deep_q.learn)
# Out:
# Help on function learn in module submitted:
#
# learn(self, state, action, reward, newstate)
#     Perform one iteration of training on a deep-Q model.
#
#     @params:
#     state: a list of 5 floats: ball_x, ball_y, ball_vx, ball_vy, paddle_y
#     action: an integer, one of -1, 0, or +1
#     reward: a reward; positive for hitting the ball, negative for losing a game
#     newstate: a list of 5 floats, in the same format as state
#
#     @return:
#     None

# %%
help(submitted.deep_q.save)
# Out:
# Help on function save in module submitted:
#
# save(self, filename)
#     Save your trained deep-Q model to a file.
#     This can save in any format you like, as long as your "load"
#     function uses the same file format.
#
#     @params:
#     filename (str) - filename to which it should be saved
#     @return:
#     None

# %%
help(submitted.deep_q.load)
# Out:
# Help on function load in module submitted:
#
# load(self, filename)
#     Load your deep-Q model from a file.
#     This should load from whatever file format your save function
#     used.
#
#     @params:
#     filename (str) - filename from which it should be loaded
#     @return:
#     None

# %% [markdown]
# <a id='grade'></a>

# %% [markdown]
# ## Grade your homework

# %% [markdown]
# If you've reached this point, and all of the above sections work, then you're ready to try grading your homework!  Before you submit it to Gradescope, try grading it on your own machine.  This will run some visible test cases (which you can read in `tests/test_visible.py`), and compare the results to the solutions (which you can read in `solution.json`).
#
# The exclamation point (!) tells python to run the following as a shell command.  Obviously you don't need to run the code this way -- this usage is here just to remind you that you can also, if you wish, run this command in a terminal window.

# %%
# !python grade.py
# Out:
# .....Completed 0 games, 30 rewards, 8125 frames, score 29, max score 29
# Completed 1 games, 48 rewards, 10886 frames, score 17, max score 29
# Completed 2 games, 64 rewards, 16802 frames, score 15, max score 29
# Completed 3 games, 71 rewards, 21221 frames, score 6, max score 29
# Completed 4 games, 86 rewards, 25431 frames, score 14, max score 29
# Completed 5 games, 89 rewards, 26294 frames, score 2, max score 29
# Completed 6 games, 99 rewards, 29810 frames, score 9, max score 29
# Completed 7 games, 119 rewards, 33539 frames, score 19, max score 29
# Completed 8 games, 131 rewards, 37423 frames, score 11, max score 29
# Completed 9 games, 133 rewards, 38157 frames, score 1, max score 29
# .
# ----------------------------------------------------------------------
# Ran 6 tests in 1.187s
#
# OK

# %% [markdown]
# Now you should try uploading your code to <a href="https://www.gradescope.com/courses/486387">Gradescope</a>.
#
# **Warning:** For this MP you need to update two files, not just one.
# * `trained_model.npz` should contain your trained model
# * `submitted.py` should contain your code that loads and runs your trained model.
#
# **Warning:** The autograder calculates the average score over ten random games.  If you are getting an average score above 10 almost all the time on your own computer, and if the autograder says you had a score below 10, try resubmitting to see if the next round of random games is better.
#
# **Extra Credit:** Your extra credit should also be uploaded as two files,
# * `trained_model.pkl` should contain your trained model
# * `submitted.py` should contain your code that loads and runs your trained model.
